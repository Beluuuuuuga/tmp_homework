# %% [markdown]
# # Install library

# %%
import os
import random

import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import KFold, StratifiedKFold

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def set_randvalue(value):
    # Set a seed value
    seed_value= value 
    # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
    os.environ['PYTHONHASHSEED']=str(seed_value)
    # 2. Set `python` built-in pseudo-random generator at a fixed value
    random.seed(seed_value)
    # 3. Set `numpy` pseudo-random generator at a fixed value
    np.random.seed(seed_value)
    # 4. Set `tensorflow` pseudo-random generator at a fixed value
    tf.random.set_seed(seed_value)

set_randvalue(42)

# %% [markdown]
# ## Dataset preprocessing and EDA

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # load data
x_train,x_test = x_train.astype('float32')/255.0,x_test.astype('float32')/255.0 # normalization

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# #### Limit three class preprocessing

# %%
# No method on keras to get cifar10 category label name by categoly label?
cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])

bird_num = np.where(cifar10_labels=='bird')
deer_num = np.where(cifar10_labels=='deer')
truck_num = np.where(cifar10_labels=='truck')

limit_num = 2500

# get limit label indexes
bird_indexes = [i for i, label in enumerate(y_train) if label == bird_num]
deer_indexes = [i for i, label in enumerate(y_train) if label == deer_num] 
truck_indexes = [i for i, label in enumerate(y_train) if label == truck_num] 
other_indexes = [i for i, label in enumerate(y_train) if label not in [bird_num, deer_num, truck_num]]

# limit
bird_indexes = bird_indexes[:limit_num]
deer_indexes = deer_indexes[:limit_num]
truck_indexes = truck_indexes[:limit_num]
print(f'Bird label num is {len(bird_indexes)}') # 2500
print(f'Deer label num is {len(deer_indexes)}') # 2500
print(f'Truck label num is {len(truck_indexes)}') # 2500
print(f'Other label num is {len(other_indexes)}') # 35000; 5000*7

# merge and sort
merge_indexes = np.concatenate([other_indexes, bird_indexes, deer_indexes, truck_indexes], 0)
merge_indexes.sort()
print(f'Train label num is {len(merge_indexes)}') # 42500

# create three labels removed train data
x_train_removed =  np.zeros((len(merge_indexes), 32, 32, 3))
y_train_removed =  np.zeros(len(merge_indexes))

for i, train_index in enumerate(merge_indexes):
    x_train_removed[i] = x_train[train_index]
    y_train_removed[i] = y_train[train_index]
    
print(x_train_removed.shape)
print(y_train_removed.shape)
# Out:
# Bird label num is 2500
# Deer label num is 2500
# Truck label num is 2500
# Other label num is 35000
# Train label num is 42500
# (42500, 32, 32, 3)
# (42500,)

# %%
# df = pd.DataFrame(y_train_removed.flatten())
df = pd.DataFrame(y_train_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    5000
# 7.0    5000
# 6.0    5000
# 5.0    5000
# 3.0    5000
# 1.0    5000
# 0.0    5000
# 9.0    2500
# 4.0    2500
# 2.0    2500
# dtype: int64

# %%
import matplotlib.pyplot as plt

# plot data labels
plt.hist(y_train_removed.flatten())
# Out:
# (array([5000., 5000., 2500., 5000., 2500., 5000., 5000., 5000., 5000.,
#         2500.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## AutoEncoder

# %% [markdown]
# #### Load AE models weight

# %%
# Batch Norm Model
def create_AE01_model(k_size):
    input_img = Input(shape=(32, 32, 3))  # 0
    conv1 = Conv2D(64, (k_size, k_size), padding='same', name="Dense_AE01_1")(input_img) # 1
    conv1 = BatchNormalization(name="BN_AE01_1")(conv1) # 2
    conv1 = Activation('relu', name="Relu_AE01_1")(conv1) # 3
        
    decoded = Conv2D(3, (k_size, k_size), padding='same', name="Dense_AE01_2")(conv1) # 4
    decoded = BatchNormalization(name="BN_AE01_2")(decoded) # 5
    decoded = Activation('relu', name="Relu_AE01_2")(decoded) # 6
    return Model(input_img, decoded)

class AE01():
    def __init__(self, ksize, optimizer):
        self.optimizer = optimizer
        
        self.autoencoder = create_AE01_model(ksize)
        self.encoder = None

    def compile(self, optimizer='adam', loss='binary_crossentropy'):
        self.autoencoder.compile(optimizer=self.optimizer, loss=loss)

    def train(self, x_train=None, x_test=None, epochs=1, batch_size=32, shuffle=True):
        es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
        ae_model_path = '../models/AE/AE01_AE_Best.hdf5'
        cp_cb = ModelCheckpoint(filepath = ae_model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
       
        history = self.autoencoder.fit(x_train, x_train,
                             epochs=epochs,
                             batch_size=batch_size,
                             shuffle=shuffle,
                             callbacks=[es_cb, cp_cb],
                             validation_data=(x_test, x_test))
        
        self.autoencoder.load_weights(ae_model_path)
        
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        encode_model_path = '../models/AE/AE01_Encoder_Best.hdf5'
        self.encoder.save(encode_model_path)
        return history
    
    def load_weights(self, ae_model_path, encode_model_path):
        self.autoencoder.load_weights(ae_model_path)
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        self.encoder.load_weights(encode_model_path)

# %%
ae_ksize = 3
ae_optimizer = 'rmsprop'
stack01 = AE01(ae_ksize, ae_optimizer)
stack01.load_weights('../models/AE/AE01_AE_Best.hdf5', '../models/AE/AE01_Encoder_Best.hdf5')
stack01.encoder.trainable = False
stack01.encoder.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# =================================================================
# Total params: 2,048
# Trainable params: 0
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ## Train

# %% [markdown]
# #### Create Model AE to CNN

# %%
def create_StackedAE01_CNN01_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(output)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 16,16,64
    
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 8,8,128
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    y = Dense(10,activation = "softmax")(x)

    return Model(input_img, y)

# %% [markdown]
# #### Over sampling without data augumentation & Cross validation

# %%
# %%time

cifar10_labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck']

# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))
cv_acc = 0
cv_f1 = 0 

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model01 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model01.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])
    
    # get target label num
    y_train_ = y_train_removed[train_index]
    df_train = pd.DataFrame(y_train_, columns=['label'])
    target_index = df_train[df_train['label'] == cifar10_labels.index('dog')].index # bird label
    limit_num = len(target_index)

    # concat nate for over sampling
    train_index_oversampling = np.concatenate([
        # target label
        df_train[df_train['label'] == cifar10_labels.index('bird')].sample(limit_num, random_state=42, replace=True).index.values, # bird
        df_train[df_train['label'] == cifar10_labels.index('deer')].sample(limit_num, random_state=42, replace=True).index.values, # deer
        df_train[df_train['label'] == cifar10_labels.index('truck')].sample(limit_num, random_state=42, replace=True).index.values, # truck
        # other label
        df_train[df_train['label'] == cifar10_labels.index('airplane')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('automobile')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('cat')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('dog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('frog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('horse')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('ship')].index.values
    ])

    print(f'Target label num is {limit_num}, and total label num is {len(train_index_oversampling)}')
    
    x_train_ = x_train_removed[train_index_oversampling]
    y_train_ = y_train_removed[train_index_oversampling]
    
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_019_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    model01_history = model01.fit(x_train_, y_train_onehot,
                          batch_size=32,
                          epochs=400,
                          verbose=1,
                          validation_data=(x_valid_, y_valid_onehot),
                          callbacks=[es_cb, cp_cb],
                          shuffle=True)
    
    # inference
    model01.load_weights(chkpt)
    scores = model01.evaluate(x_valid_, y_valid_onehot)
    
    # CV value
    cv_acc += scores[1]*100
    y_valid_pred =  model01.predict(x_valid_)
    y_valid_pred = np.argmax(y_valid_pred, axis=1)
    cv_f1 += f1_score(y_valid_, y_valid_pred, average='macro')*100
    
    print(f'Score for fold {fold_no}: {model01.metrics_names[0]} of {scores[0]}; {model01.metrics_names[1]} of {scores[1]*100}%')
    
    predict = model01.predict(x_test)
    predicts += predict
    
    histories.append(model01_history.history)
    fold_no += 1
# Out:
# Target label num is 3334, and total label num is 33336
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.3861 - accuracy: 0.5002
# Epoch 00001: val_loss improved from inf to 1.24605, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.3861 - accuracy: 0.5002 - val_loss: 1.2461 - val_accuracy: 0.5646
# Epoch 2/400
# 1042/1042 [==============================] - ETA: 0s - loss: 0.9606 - accuracy: 0.6624
# Epoch 00002: val_loss improved from 1.24605 to 1.01143, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.9606 - accuracy: 0.6624 - val_loss: 1.0114 - val_accuracy: 0.6498
# Epoch 3/400
# 1040/1042 [============================>.] - ETA: 0s - loss: 0.7600 - accuracy: 0.7371
# Epoch 00003: val_loss improved from 1.01143 to 0.90351, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.7601 - accuracy: 0.7370 - val_loss: 0.9035 - val_accuracy: 0.6896
# Epoch 4/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.6220 - accuracy: 0.7835
# Epoch 00004: val_loss improved from 0.90351 to 0.70483, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.6217 - accuracy: 0.7835 - val_loss: 0.7048 - val_accuracy: 0.7521
# Epoch 5/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.5127 - accuracy: 0.8243
# Epoch 00005: val_loss improved from 0.70483 to 0.62329, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.5131 - accuracy: 0.8242 - val_loss: 0.6233 - val_accuracy: 0.7897
# Epoch 6/400
# 1037/1042 [============================>.] - ETA: 0s - loss: 0.4330 - accuracy: 0.8486
# Epoch 00006: val_loss improved from 0.62329 to 0.54746, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.4329 - accuracy: 0.8484 - val_loss: 0.5475 - val_accuracy: 0.8200
# Epoch 7/400
# 1036/1042 [============================>.] - ETA: 0s - loss: 0.3581 - accuracy: 0.8757
# Epoch 00007: val_loss did not improve from 0.54746
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.3584 - accuracy: 0.8757 - val_loss: 0.8060 - val_accuracy: 0.7527
# Epoch 8/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.3000 - accuracy: 0.8968
# Epoch 00008: val_loss improved from 0.54746 to 0.52877, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.3000 - accuracy: 0.8970 - val_loss: 0.5288 - val_accuracy: 0.8340
# Epoch 9/400
# 1036/1042 [============================>.] - ETA: 0s - loss: 0.2516 - accuracy: 0.9130
# Epoch 00009: val_loss did not improve from 0.52877
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2516 - accuracy: 0.9131 - val_loss: 0.5415 - val_accuracy: 0.8350
# Epoch 10/400
# 1042/1042 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.9275
# Epoch 00010: val_loss did not improve from 0.52877
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2073 - accuracy: 0.9275 - val_loss: 0.5811 - val_accuracy: 0.8361
# Epoch 11/400
# 1032/1042 [============================>.] - ETA: 0s - loss: 0.1882 - accuracy: 0.9352
# Epoch 00011: val_loss improved from 0.52877 to 0.40315, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1883 - accuracy: 0.9351 - val_loss: 0.4031 - val_accuracy: 0.8871
# Epoch 12/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9447
# Epoch 00012: val_loss did not improve from 0.40315
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1593 - accuracy: 0.9444 - val_loss: 0.6962 - val_accuracy: 0.8296
# Epoch 13/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.1430 - accuracy: 0.9507
# Epoch 00013: val_loss did not improve from 0.40315
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1430 - accuracy: 0.9507 - val_loss: 0.6195 - val_accuracy: 0.8425
# Epoch 14/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9539
# Epoch 00014: val_loss improved from 0.40315 to 0.39777, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1275 - accuracy: 0.9539 - val_loss: 0.3978 - val_accuracy: 0.8962
# Epoch 15/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.1224 - accuracy: 0.9571
# Epoch 00015: val_loss did not improve from 0.39777
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1229 - accuracy: 0.9571 - val_loss: 0.4902 - val_accuracy: 0.8875
# Epoch 16/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9601
# Epoch 00016: val_loss did not improve from 0.39777
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1155 - accuracy: 0.9600 - val_loss: 0.5382 - val_accuracy: 0.8713
# Epoch 17/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9633
# Epoch 00017: val_loss did not improve from 0.39777
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1077 - accuracy: 0.9633 - val_loss: 0.4642 - val_accuracy: 0.8894
# Epoch 00017: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.3978 - accuracy: 0.8962
# Score for fold 1: loss of 0.3977714776992798; accuracy of 89.61671590805054%
# Target label num is 3333, and total label num is 33331
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.3828 - accuracy: 0.4983
# Epoch 00001: val_loss improved from inf to 1.08637, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.3828 - accuracy: 0.4983 - val_loss: 1.0864 - val_accuracy: 0.6058
# Epoch 2/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.9626 - accuracy: 0.6598
# Epoch 00002: val_loss improved from 1.08637 to 1.04853, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.9619 - accuracy: 0.6599 - val_loss: 1.0485 - val_accuracy: 0.6399
# Epoch 3/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.7728 - accuracy: 0.7300
# Epoch 00003: val_loss improved from 1.04853 to 0.85751, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.7726 - accuracy: 0.7303 - val_loss: 0.8575 - val_accuracy: 0.6998
# Epoch 4/400
# 1032/1042 [============================>.] - ETA: 0s - loss: 0.6172 - accuracy: 0.7861
# Epoch 00004: val_loss improved from 0.85751 to 0.59862, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.6172 - accuracy: 0.7861 - val_loss: 0.5986 - val_accuracy: 0.7916
# Epoch 5/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.5061 - accuracy: 0.8267
# Epoch 00005: val_loss did not improve from 0.59862
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.5063 - accuracy: 0.8265 - val_loss: 0.6830 - val_accuracy: 0.7695
# Epoch 6/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.4273 - accuracy: 0.8509
# Epoch 00006: val_loss did not improve from 0.59862
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.4272 - accuracy: 0.8509 - val_loss: 0.7019 - val_accuracy: 0.7762
# Epoch 7/400
# 1040/1042 [============================>.] - ETA: 0s - loss: 0.3513 - accuracy: 0.8773
# Epoch 00007: val_loss improved from 0.59862 to 0.57279, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.3511 - accuracy: 0.8774 - val_loss: 0.5728 - val_accuracy: 0.8141
# Epoch 8/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.2938 - accuracy: 0.8987
# Epoch 00008: val_loss improved from 0.57279 to 0.57165, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2939 - accuracy: 0.8986 - val_loss: 0.5717 - val_accuracy: 0.8250
# Epoch 9/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.2473 - accuracy: 0.9129
# Epoch 00009: val_loss improved from 0.57165 to 0.52877, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2478 - accuracy: 0.9129 - val_loss: 0.5288 - val_accuracy: 0.8411
# Epoch 10/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.2123 - accuracy: 0.9233
# Epoch 00010: val_loss improved from 0.52877 to 0.47894, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2123 - accuracy: 0.9233 - val_loss: 0.4789 - val_accuracy: 0.8568
# Epoch 11/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9373
# Epoch 00011: val_loss did not improve from 0.47894
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1807 - accuracy: 0.9371 - val_loss: 0.4795 - val_accuracy: 0.8655
# Epoch 12/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 0.1632 - accuracy: 0.9433
# Epoch 00012: val_loss improved from 0.47894 to 0.44019, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1637 - accuracy: 0.9430 - val_loss: 0.4402 - val_accuracy: 0.8801
# Epoch 13/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.1473 - accuracy: 0.9484
# Epoch 00013: val_loss improved from 0.44019 to 0.42181, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1477 - accuracy: 0.9485 - val_loss: 0.4218 - val_accuracy: 0.8782
# Epoch 14/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.1207 - accuracy: 0.9576
# Epoch 00014: val_loss did not improve from 0.42181
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1210 - accuracy: 0.9575 - val_loss: 0.5207 - val_accuracy: 0.8679
# Epoch 15/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.9588
# Epoch 00015: val_loss did not improve from 0.42181
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1191 - accuracy: 0.9587 - val_loss: 0.4451 - val_accuracy: 0.8892
# Epoch 16/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 0.1117 - accuracy: 0.9608
# Epoch 00016: val_loss did not improve from 0.42181
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1118 - accuracy: 0.9608 - val_loss: 0.4413 - val_accuracy: 0.8892
# Epoch 00016: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8782
# Score for fold 2: loss of 0.4218052625656128; accuracy of 87.82381415367126%
# Target label num is 3333, and total label num is 33333
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.4000 - accuracy: 0.4962
# Epoch 00001: val_loss improved from inf to 1.57034, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.4000 - accuracy: 0.4962 - val_loss: 1.5703 - val_accuracy: 0.4555
# Epoch 2/400
# 1036/1042 [============================>.] - ETA: 0s - loss: 1.0005 - accuracy: 0.6430
# Epoch 00002: val_loss improved from 1.57034 to 1.01601, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.9995 - accuracy: 0.6436 - val_loss: 1.0160 - val_accuracy: 0.6385
# Epoch 3/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.8031 - accuracy: 0.7184
# Epoch 00003: val_loss improved from 1.01601 to 0.79222, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.8031 - accuracy: 0.7184 - val_loss: 0.7922 - val_accuracy: 0.7230
# Epoch 4/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.6533 - accuracy: 0.7727
# Epoch 00004: val_loss did not improve from 0.79222
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.6534 - accuracy: 0.7727 - val_loss: 0.9100 - val_accuracy: 0.6892
# Epoch 5/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.8132
# Epoch 00005: val_loss improved from 0.79222 to 0.76877, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.5416 - accuracy: 0.8134 - val_loss: 0.7688 - val_accuracy: 0.7457
# Epoch 6/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 0.4586 - accuracy: 0.8430
# Epoch 00006: val_loss improved from 0.76877 to 0.61781, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.4588 - accuracy: 0.8429 - val_loss: 0.6178 - val_accuracy: 0.7912
# Epoch 7/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.3848 - accuracy: 0.8666
# Epoch 00007: val_loss improved from 0.61781 to 0.59830, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.3861 - accuracy: 0.8661 - val_loss: 0.5983 - val_accuracy: 0.8088
# Epoch 8/400
# 1037/1042 [============================>.] - ETA: 0s - loss: 0.3152 - accuracy: 0.8911
# Epoch 00008: val_loss did not improve from 0.59830
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.3150 - accuracy: 0.8911 - val_loss: 0.6258 - val_accuracy: 0.8017
# Epoch 9/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.2668 - accuracy: 0.9078
# Epoch 00009: val_loss did not improve from 0.59830
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2671 - accuracy: 0.9076 - val_loss: 0.6165 - val_accuracy: 0.8191
# Epoch 10/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.2278 - accuracy: 0.9206
# Epoch 00010: val_loss improved from 0.59830 to 0.47344, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.2280 - accuracy: 0.9204 - val_loss: 0.4734 - val_accuracy: 0.8561
# Epoch 11/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9308
# Epoch 00011: val_loss did not improve from 0.47344
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1894 - accuracy: 0.9308 - val_loss: 0.5352 - val_accuracy: 0.8484
# Epoch 12/400
# 1036/1042 [============================>.] - ETA: 0s - loss: 0.1715 - accuracy: 0.9398
# Epoch 00012: val_loss did not improve from 0.47344
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1717 - accuracy: 0.9398 - val_loss: 0.4998 - val_accuracy: 0.8686
# Epoch 13/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.1538 - accuracy: 0.9462
# Epoch 00013: val_loss did not improve from 0.47344
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.1540 - accuracy: 0.9462 - val_loss: 0.5232 - val_accuracy: 0.8614
# Epoch 00013: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.4734 - accuracy: 0.8561
# Score for fold 3: loss of 0.4734417498111725; accuracy of 85.61344146728516%
# Wall time: 4min 41s

# %%
ensemble_histories = histories
ensemble_predicts = predicts
ensemble_predicts_ = ensemble_predicts / n_splits
y_pred = np.argmax(ensemble_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      1000
#            1       0.89      0.89      0.89      1000
#            2       0.78      0.64      0.71      1000
#            3       0.68      0.62      0.65      1000
#            4       0.71      0.79      0.75      1000
#            5       0.75      0.71      0.73      1000
#            6       0.84      0.80      0.82      1000
#            7       0.76      0.89      0.82      1000
#            8       0.87      0.87      0.87      1000
#            9       0.83      0.89      0.86      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000

# %%
print(f'CV ACC is {cv_acc//n_splits},n_splits CV macro F1 is {cv_f1//n_splits}')
# Out:
# CV ACC is 87.0,n_splits CV macro F1 is 87.0

# %% [markdown]
# #### Over sampling with data augumentation

# %%
# %%time

cifar10_labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck']

# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))
cv_acc = 0
cv_f1 = 0 

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model02 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model02.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

    # get target label num
    y_train_ = y_train_removed[train_index]
    df_train = pd.DataFrame(y_train_, columns=['label'])
    target_index = df_train[df_train['label'] == cifar10_labels.index('dog')].index # bird label
    limit_num = len(target_index)

    # concat nate for over sampling
    train_index_oversampling = np.concatenate([
        # target label
        df_train[df_train['label'] == cifar10_labels.index('bird')].sample(limit_num, random_state=42, replace=True).index.values, # bird
        df_train[df_train['label'] == cifar10_labels.index('deer')].sample(limit_num, random_state=42, replace=True).index.values, # deer
        df_train[df_train['label'] == cifar10_labels.index('truck')].sample(limit_num, random_state=42, replace=True).index.values, # truck
        # other label
        df_train[df_train['label'] == cifar10_labels.index('airplane')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('automobile')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('cat')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('dog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('frog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('horse')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('ship')].index.values
    ])

    print(f'Target label num is {limit_num}, and total label num is {len(train_index_oversampling)}')
    
    x_train_ = x_train_removed[train_index_oversampling]
    y_train_ = y_train_removed[train_index_oversampling]
    
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_020_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    # create generator
    train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=10,
#         shear_range=0.2,
        horizontal_flip=True,
#         vertical_flip=True,
#         width_shift_range=0.1,
#         height_shift_range=0.1,
        zoom_range=0.1
#         channel_shift_range=0.2
        )

    batch_size = 32
    train_datagenerator = train_datagen.flow(x_train_, y_train_onehot, batch_size)
    valid_datagenerator = ImageDataGenerator().flow(x_valid_, y_valid_onehot, batch_size)

    model02_history = model02.fit_generator(train_datagenerator,
                                  steps_per_epoch=int(len(x_train_)//batch_size),
                                  epochs=400,
                                  validation_data=valid_datagenerator,
                                  validation_steps=int(len(x_valid_)//batch_size),
                                  verbose=1,
                                  shuffle=True,
                                  callbacks=[es_cb, cp_cb])

    # inference
    model02.load_weights(chkpt)
    scores = model02.evaluate(x_valid_, y_valid_onehot)
    
    # CV value
    cv_acc += scores[1]*100
    y_valid_pred =  model02.predict(x_valid_)
    y_valid_pred = np.argmax(y_valid_pred, axis=1)
    cv_f1 += f1_score(y_valid_, y_valid_pred, average='macro')*100
    
    print(f'Score for fold {fold_no}: {model02.metrics_names[0]} of {scores[0]}; {model02.metrics_names[1]} of {scores[1]*100}%')
    
    predict = model02.predict(x_test)
    predicts += predict
    
    histories.append(model02_history.history)
    fold_no += 1
# Out:
# Target label num is 3334, and total label num is 33336
# WARNING:tensorflow:From <timed exec>:97: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 1.4429 - accuracy: 0.4799
# Epoch 00001: val_loss improved from inf to 1.32883, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 10s 9ms/step - loss: 1.4426 - accuracy: 0.4801 - val_loss: 1.3288 - val_accuracy: 0.5452
# Epoch 2/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 1.0612 - accuracy: 0.6219
# Epoch 00002: val_loss improved from 1.32883 to 1.16777, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 10s 9ms/step - loss: 1.0611 - accuracy: 0.6220 - val_loss: 1.1678 - val_accuracy: 0.6015
# Epoch 3/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.8695 - accuracy: 0.6931
# Epoch 00003: val_loss did not improve from 1.16777
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.8691 - accuracy: 0.6933 - val_loss: 1.3219 - val_accuracy: 0.6162
# Epoch 4/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.7607 - accuracy: 0.7337
# Epoch 00004: val_loss improved from 1.16777 to 0.79911, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7605 - accuracy: 0.7338 - val_loss: 0.7991 - val_accuracy: 0.7234
# Epoch 5/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.6793 - accuracy: 0.7647
# Epoch 00005: val_loss improved from 0.79911 to 0.75418, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6787 - accuracy: 0.7650 - val_loss: 0.7542 - val_accuracy: 0.7452
# Epoch 6/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.6153 - accuracy: 0.7873
# Epoch 00006: val_loss improved from 0.75418 to 0.63291, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6153 - accuracy: 0.7873 - val_loss: 0.6329 - val_accuracy: 0.7830
# Epoch 7/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.5629 - accuracy: 0.8058
# Epoch 00007: val_loss improved from 0.63291 to 0.61293, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5631 - accuracy: 0.8058 - val_loss: 0.6129 - val_accuracy: 0.7901
# Epoch 8/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.5196 - accuracy: 0.8201
# Epoch 00008: val_loss did not improve from 0.61293
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5193 - accuracy: 0.8203 - val_loss: 0.7368 - val_accuracy: 0.7627
# Epoch 9/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.4858 - accuracy: 0.8314
# Epoch 00009: val_loss did not improve from 0.61293
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4865 - accuracy: 0.8313 - val_loss: 0.6999 - val_accuracy: 0.7717
# Epoch 10/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.4499 - accuracy: 0.8455
# Epoch 00010: val_loss did not improve from 0.61293
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4499 - accuracy: 0.8452 - val_loss: 0.7623 - val_accuracy: 0.7630
# Epoch 00010: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6126 - accuracy: 0.7901
# Score for fold 1: loss of 0.6126269698143005; accuracy of 79.00755405426025%
# Target label num is 3333, and total label num is 33331
# Epoch 1/400
# 1041/1041 [==============================] - ETA: 0s - loss: 1.4388 - accuracy: 0.4789
# Epoch 00001: val_loss improved from inf to 1.36417, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 10s 9ms/step - loss: 1.4388 - accuracy: 0.4789 - val_loss: 1.3642 - val_accuracy: 0.5011
# Epoch 2/400
# 1041/1041 [==============================] - ETA: 0s - loss: 1.0514 - accuracy: 0.6253
# Epoch 00002: val_loss improved from 1.36417 to 1.23803, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.0514 - accuracy: 0.6253 - val_loss: 1.2380 - val_accuracy: 0.5769
# Epoch 3/400
# 1038/1041 [============================>.] - ETA: 0s - loss: 0.8725 - accuracy: 0.6934
# Epoch 00003: val_loss improved from 1.23803 to 0.81340, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.8728 - accuracy: 0.6936 - val_loss: 0.8134 - val_accuracy: 0.7128
# Epoch 4/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.7543 - accuracy: 0.7371
# Epoch 00004: val_loss did not improve from 0.81340
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7538 - accuracy: 0.7372 - val_loss: 0.9224 - val_accuracy: 0.6954
# Epoch 5/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.6816 - accuracy: 0.7629
# Epoch 00005: val_loss improved from 0.81340 to 0.76227, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6816 - accuracy: 0.7628 - val_loss: 0.7623 - val_accuracy: 0.7473
# Epoch 6/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.7879
# Epoch 00006: val_loss did not improve from 0.76227
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6140 - accuracy: 0.7881 - val_loss: 0.7712 - val_accuracy: 0.7474
# Epoch 7/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.5650 - accuracy: 0.8039
# Epoch 00007: val_loss improved from 0.76227 to 0.61268, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5653 - accuracy: 0.8038 - val_loss: 0.6127 - val_accuracy: 0.7933
# Epoch 8/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.5249 - accuracy: 0.8152
# Epoch 00008: val_loss did not improve from 0.61268
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5255 - accuracy: 0.8150 - val_loss: 0.6714 - val_accuracy: 0.7711
# Epoch 9/400
# 1038/1041 [============================>.] - ETA: 0s - loss: 0.4872 - accuracy: 0.8303
# Epoch 00009: val_loss did not improve from 0.61268
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4870 - accuracy: 0.8304 - val_loss: 0.6187 - val_accuracy: 0.7892
# Epoch 10/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.4520 - accuracy: 0.8419
# Epoch 00010: val_loss did not improve from 0.61268
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4521 - accuracy: 0.8419 - val_loss: 0.6897 - val_accuracy: 0.7782
# Epoch 00010: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6121 - accuracy: 0.7935
# Score for fold 2: loss of 0.6120786070823669; accuracy of 79.35342788696289%
# Target label num is 3333, and total label num is 33333
# Epoch 1/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 1.4586 - accuracy: 0.4750
# Epoch 00001: val_loss improved from inf to 1.14104, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 10s 9ms/step - loss: 1.4572 - accuracy: 0.4757 - val_loss: 1.1410 - val_accuracy: 0.5852
# Epoch 2/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 1.0840 - accuracy: 0.6116
# Epoch 00002: val_loss improved from 1.14104 to 1.03209, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.0835 - accuracy: 0.6119 - val_loss: 1.0321 - val_accuracy: 0.6289
# Epoch 3/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.9009 - accuracy: 0.6830
# Epoch 00003: val_loss did not improve from 1.03209
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.9014 - accuracy: 0.6829 - val_loss: 1.0599 - val_accuracy: 0.6396
# Epoch 4/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.7835 - accuracy: 0.7254
# Epoch 00004: val_loss improved from 1.03209 to 0.79959, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7834 - accuracy: 0.7254 - val_loss: 0.7996 - val_accuracy: 0.7280
# Epoch 5/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.6998 - accuracy: 0.7573
# Epoch 00005: val_loss improved from 0.79959 to 0.63462, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6995 - accuracy: 0.7575 - val_loss: 0.6346 - val_accuracy: 0.7817
# Epoch 6/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.6269 - accuracy: 0.7824
# Epoch 00006: val_loss improved from 0.63462 to 0.63138, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6270 - accuracy: 0.7823 - val_loss: 0.6314 - val_accuracy: 0.7877
# Epoch 7/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.5781 - accuracy: 0.8002
# Epoch 00007: val_loss did not improve from 0.63138
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5785 - accuracy: 0.8001 - val_loss: 0.8116 - val_accuracy: 0.7405
# Epoch 8/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.5272 - accuracy: 0.8184
# Epoch 00008: val_loss did not improve from 0.63138
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5271 - accuracy: 0.8185 - val_loss: 0.6334 - val_accuracy: 0.7854
# Epoch 9/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.4959 - accuracy: 0.8303
# Epoch 00009: val_loss did not improve from 0.63138
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4960 - accuracy: 0.8303 - val_loss: 0.8111 - val_accuracy: 0.7373
# Epoch 00009: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6311 - accuracy: 0.7876
# Score for fold 3: loss of 0.6310860514640808; accuracy of 78.75900268554688%
# Wall time: 4min 45s

# %%
ensemble_dataaug_histories = histories
ensemble_dataaug_predicts = predicts
ensemble_dataaug_predicts_ = ensemble_dataaug_predicts / n_splits
y_pred = np.argmax(ensemble_dataaug_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.78      1000
#            1       0.82      0.93      0.87      1000
#            2       0.75      0.64      0.69      1000
#            3       0.75      0.48      0.59      1000
#            4       0.82      0.69      0.75      1000
#            5       0.68      0.79      0.73      1000
#            6       0.71      0.89      0.79      1000
#            7       0.80      0.85      0.83      1000
#            8       0.91      0.82      0.86      1000
#            9       0.83      0.87      0.85      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.77     10000
# weighted avg       0.78      0.78      0.77     10000

# %%
print(f'CV ACC is {cv_acc//n_splits},n_splits CV macro F1 is {cv_f1//n_splits}')
# Out:
# CV ACC is 79.0,n_splits CV macro F1 is 78.0
