# %% [markdown]
# # Install library

# %%
import os
import random

import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import KFold, StratifiedKFold

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def set_randvalue(value):
    # Set a seed value
    seed_value= value 
    # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
    os.environ['PYTHONHASHSEED']=str(seed_value)
    # 2. Set `python` built-in pseudo-random generator at a fixed value
    random.seed(seed_value)
    # 3. Set `numpy` pseudo-random generator at a fixed value
    np.random.seed(seed_value)
    # 4. Set `tensorflow` pseudo-random generator at a fixed value
    tf.random.set_seed(seed_value)

set_randvalue(42)

# %% [markdown]
# ## Dataset preprocessing and EDA

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # load data
x_train,x_test = x_train.astype('float32')/255.0,x_test.astype('float32')/255.0 # normalization

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# #### Limit three class preprocessing

# %%
# No method on keras to get cifar10 category label name by categoly label?
cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])

bird_num = np.where(cifar10_labels=='bird')
deer_num = np.where(cifar10_labels=='deer')
truck_num = np.where(cifar10_labels=='truck')

limit_num = 2500

# get limit label indexes
bird_indexes = [i for i, label in enumerate(y_train) if label == bird_num]
deer_indexes = [i for i, label in enumerate(y_train) if label == deer_num] 
truck_indexes = [i for i, label in enumerate(y_train) if label == truck_num] 
other_indexes = [i for i, label in enumerate(y_train) if label not in [bird_num, deer_num, truck_num]]

# limit
bird_indexes = bird_indexes[:limit_num]
deer_indexes = deer_indexes[:limit_num]
truck_indexes = truck_indexes[:limit_num]
print(f'Bird label num is {len(bird_indexes)}') # 2500
print(f'Deer label num is {len(deer_indexes)}') # 2500
print(f'Truck label num is {len(truck_indexes)}') # 2500
print(f'Other label num is {len(other_indexes)}') # 35000; 5000*7

# merge and sort
merge_indexes = np.concatenate([other_indexes, bird_indexes, deer_indexes, truck_indexes], 0)
merge_indexes.sort()
print(f'Train label num is {len(merge_indexes)}') # 42500

# create three labels removed train data
x_train_removed =  np.zeros((len(merge_indexes), 32, 32, 3))
y_train_removed =  np.zeros(len(merge_indexes))

for i, train_index in enumerate(merge_indexes):
    x_train_removed[i] = x_train[train_index]
    y_train_removed[i] = y_train[train_index]
    
print(x_train_removed.shape)
print(y_train_removed.shape)
# Out:
# Bird label num is 2500
# Deer label num is 2500
# Truck label num is 2500
# Other label num is 35000
# Train label num is 42500
# (42500, 32, 32, 3)
# (42500,)

# %%
# df = pd.DataFrame(y_train_removed.flatten())
df = pd.DataFrame(y_train_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    5000
# 7.0    5000
# 6.0    5000
# 5.0    5000
# 3.0    5000
# 1.0    5000
# 0.0    5000
# 9.0    2500
# 4.0    2500
# 2.0    2500
# dtype: int64

# %%
import matplotlib.pyplot as plt

# plot data labels
plt.hist(y_train_removed.flatten())
# Out:
# (array([5000., 5000., 2500., 5000., 2500., 5000., 5000., 5000., 5000.,
#         2500.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## AutoEncoder

# %% [markdown]
# #### Load AE models weight

# %%
# Batch Norm Model
def create_AE01_model(k_size):
    input_img = Input(shape=(32, 32, 3))  # 0
    conv1 = Conv2D(64, (k_size, k_size), padding='same', name="Dense_AE01_1")(input_img) # 1
    conv1 = BatchNormalization(name="BN_AE01_1")(conv1) # 2
    conv1 = Activation('relu', name="Relu_AE01_1")(conv1) # 3
        
    decoded = Conv2D(3, (k_size, k_size), padding='same', name="Dense_AE01_2")(conv1) # 4
    decoded = BatchNormalization(name="BN_AE01_2")(decoded) # 5
    decoded = Activation('relu', name="Relu_AE01_2")(decoded) # 6
    return Model(input_img, decoded)

class AE01():
    def __init__(self, ksize, optimizer):
        self.optimizer = optimizer
        
        self.autoencoder = create_AE01_model(ksize)
        self.encoder = None

    def compile(self, optimizer='adam', loss='binary_crossentropy'):
        self.autoencoder.compile(optimizer=self.optimizer, loss=loss)

    def train(self, x_train=None, x_test=None, epochs=1, batch_size=32, shuffle=True):
        es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
        ae_model_path = '../models/AE/AE01_AE_Best.hdf5'
        cp_cb = ModelCheckpoint(filepath = ae_model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
       
        history = self.autoencoder.fit(x_train, x_train,
                             epochs=epochs,
                             batch_size=batch_size,
                             shuffle=shuffle,
                             callbacks=[es_cb, cp_cb],
                             validation_data=(x_test, x_test))
        
        self.autoencoder.load_weights(ae_model_path)
        
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        encode_model_path = '../models/AE/AE01_Encoder_Best.hdf5'
        self.encoder.save(encode_model_path)
        return history
    
    def load_weights(self, ae_model_path, encode_model_path):
        self.autoencoder.load_weights(ae_model_path)
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        self.encoder.load_weights(encode_model_path)

# %%
ae_ksize = 3
ae_optimizer = 'rmsprop'
stack01 = AE01(ae_ksize, ae_optimizer)
stack01.load_weights('../models/AE/AE01_AE_Best.hdf5', '../models/AE/AE01_Encoder_Best.hdf5')
stack01.encoder.trainable = False
stack01.encoder.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# =================================================================
# Total params: 2,048
# Trainable params: 0
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ## Train

# %% [markdown]
# #### Create Model AE to CNN

# %%
def create_StackedAE01_CNN01_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(output)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x) # 16,16,64
    
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x) # 8,8,128
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    y = Dense(10,activation = "softmax")(x)

    return Model(input_img, y)

# %% [markdown]
# #### Over sampling without data augumentation & Cross validation

# %%
# %%time

cifar10_labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck']

# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model01 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model01.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])
    
    # get target label num
    y_train_ = y_train_removed[train_index]
    df_train = pd.DataFrame(y_train_, columns=['label'])
    target_index = df_train[df_train['label'] == cifar10_labels.index('dog')].index # bird label
    limit_num = len(target_index)

    # concat nate for over sampling
    train_index_oversampling = np.concatenate([
        # target label
        df_train[df_train['label'] == cifar10_labels.index('bird')].sample(limit_num, random_state=42, replace=True).index.values, # bird
        df_train[df_train['label'] == cifar10_labels.index('deer')].sample(limit_num, random_state=42, replace=True).index.values, # deer
        df_train[df_train['label'] == cifar10_labels.index('truck')].sample(limit_num, random_state=42, replace=True).index.values, # truck
        # other label
        df_train[df_train['label'] == cifar10_labels.index('airplane')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('automobile')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('cat')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('dog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('frog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('horse')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('ship')].index.values
    ])

    print(f'Target label num is {limit_num}, and total label num is {len(train_index_oversampling)}')
    
    x_train_ = x_train_removed[train_index_oversampling]
    y_train_ = y_train_removed[train_index_oversampling]
    
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_019_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    model01_history = model01.fit(x_train_, y_train_onehot,
                          batch_size=32,
                          epochs=400,
                          verbose=1,
                          validation_data=(x_valid_, y_valid_onehot),
                          callbacks=[es_cb, cp_cb],
                          shuffle=True)
    
    # inference
    model01.load_weights(chkpt)
    scores = model01.evaluate(x_test, y_test_onehot)
    print(f'Score for fold {fold_no}: {model01.metrics_names[0]} of {scores[0]}; {model01.metrics_names[1]} of {scores[1]*100}%')
    
    predict = model01.predict(x_test)
    predicts += predict
    
    histories.append(model01_history.history)
    fold_no += 1
# Out:
# Target label num is 3334, and total label num is 33336
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.3908 - accuracy: 0.4963
# Epoch 00001: val_loss improved from inf to 1.30164, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.3908 - accuracy: 0.4963 - val_loss: 1.3016 - val_accuracy: 0.5377
# Epoch 2/400
# 1037/1042 [============================>.] - ETA: 0s - loss: 0.9816 - accuracy: 0.6513
# Epoch 00002: val_loss improved from 1.30164 to 0.94845, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.9811 - accuracy: 0.6515 - val_loss: 0.9484 - val_accuracy: 0.6651
# Epoch 3/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.7804 - accuracy: 0.7273
# Epoch 00003: val_loss improved from 0.94845 to 0.94728, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.7804 - accuracy: 0.7273 - val_loss: 0.9473 - val_accuracy: 0.6673
# Epoch 4/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.7809
# Epoch 00004: val_loss improved from 0.94728 to 0.61321, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.6330 - accuracy: 0.7811 - val_loss: 0.6132 - val_accuracy: 0.7839
# Epoch 5/400
# 1032/1042 [============================>.] - ETA: 0s - loss: 0.5253 - accuracy: 0.8200
# Epoch 00005: val_loss improved from 0.61321 to 0.57175, saving model to ../models/CNN\Model_019_1_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.5252 - accuracy: 0.8200 - val_loss: 0.5717 - val_accuracy: 0.8022
# Epoch 6/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.4380 - accuracy: 0.8484
# Epoch 00006: val_loss did not improve from 0.57175
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.4373 - accuracy: 0.8487 - val_loss: 0.8467 - val_accuracy: 0.7162
# Epoch 7/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8759
# Epoch 00007: val_loss did not improve from 0.57175
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.3617 - accuracy: 0.8756 - val_loss: 0.6001 - val_accuracy: 0.8027
# Epoch 8/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.3026 - accuracy: 0.8951
# Epoch 00008: val_loss did not improve from 0.57175
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.3021 - accuracy: 0.8952 - val_loss: 0.6147 - val_accuracy: 0.8058
# Epoch 00008: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8438 - accuracy: 0.7219
# Score for fold 1: loss of 0.8437563180923462; accuracy of 72.18999862670898%
# Target label num is 3333, and total label num is 33331
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.3803 - accuracy: 0.5027
# Epoch 00001: val_loss improved from inf to 1.06638, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.3803 - accuracy: 0.5027 - val_loss: 1.0664 - val_accuracy: 0.6152
# Epoch 2/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 0.9654 - accuracy: 0.6591
# Epoch 00002: val_loss improved from 1.06638 to 0.99315, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.9643 - accuracy: 0.6593 - val_loss: 0.9932 - val_accuracy: 0.6603
# Epoch 3/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.7672 - accuracy: 0.7325
# Epoch 00003: val_loss improved from 0.99315 to 0.80705, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.7673 - accuracy: 0.7325 - val_loss: 0.8071 - val_accuracy: 0.7206
# Epoch 4/400
# 1040/1042 [============================>.] - ETA: 0s - loss: 0.6198 - accuracy: 0.7842
# Epoch 00004: val_loss improved from 0.80705 to 0.68321, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.6198 - accuracy: 0.7843 - val_loss: 0.6832 - val_accuracy: 0.7597
# Epoch 5/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.5064 - accuracy: 0.8239
# Epoch 00005: val_loss improved from 0.68321 to 0.67660, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.5067 - accuracy: 0.8239 - val_loss: 0.6766 - val_accuracy: 0.7661
# Epoch 6/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.8506
# Epoch 00006: val_loss improved from 0.67660 to 0.58200, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.4295 - accuracy: 0.8505 - val_loss: 0.5820 - val_accuracy: 0.8067
# Epoch 7/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8761
# Epoch 00007: val_loss did not improve from 0.58200
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.3580 - accuracy: 0.8762 - val_loss: 0.5985 - val_accuracy: 0.8055
# Epoch 8/400
# 1036/1042 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.8972
# Epoch 00008: val_loss improved from 0.58200 to 0.47342, saving model to ../models/CNN\Model_019_2_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.2963 - accuracy: 0.8973 - val_loss: 0.4734 - val_accuracy: 0.8494
# Epoch 9/400
# 1041/1042 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9111
# Epoch 00009: val_loss did not improve from 0.47342
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.2514 - accuracy: 0.9111 - val_loss: 0.5011 - val_accuracy: 0.8467
# Epoch 10/400
# 1032/1042 [============================>.] - ETA: 0s - loss: 0.2127 - accuracy: 0.9254
# Epoch 00010: val_loss did not improve from 0.47342
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.2131 - accuracy: 0.9254 - val_loss: 0.7131 - val_accuracy: 0.7942
# Epoch 11/400
# 1034/1042 [============================>.] - ETA: 0s - loss: 0.1904 - accuracy: 0.9329
# Epoch 00011: val_loss did not improve from 0.47342
# 1042/1042 [==============================] - 5s 5ms/step - loss: 0.1907 - accuracy: 0.9328 - val_loss: 0.6688 - val_accuracy: 0.8248
# Epoch 00011: early stopping
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8916 - accuracy: 0.7315
# Score for fold 2: loss of 0.8915570378303528; accuracy of 73.15000295639038%
# Target label num is 3333, and total label num is 33333
# Epoch 1/400
# 1042/1042 [==============================] - ETA: 0s - loss: 1.4009 - accuracy: 0.4932
# Epoch 00001: val_loss improved from inf to 1.22135, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 6ms/step - loss: 1.4009 - accuracy: 0.4932 - val_loss: 1.2213 - val_accuracy: 0.5702
# Epoch 2/400
# 1035/1042 [============================>.] - ETA: 0s - loss: 1.0048 - accuracy: 0.6403
# Epoch 00002: val_loss improved from 1.22135 to 0.97500, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 1.0038 - accuracy: 0.6407 - val_loss: 0.9750 - val_accuracy: 0.6627
# Epoch 3/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.8006 - accuracy: 0.7219
# Epoch 00003: val_loss improved from 0.97500 to 0.86378, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.8008 - accuracy: 0.7219 - val_loss: 0.8638 - val_accuracy: 0.7070
# Epoch 4/400
# 1040/1042 [============================>.] - ETA: 0s - loss: 0.6512 - accuracy: 0.7764
# Epoch 00004: val_loss improved from 0.86378 to 0.74137, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.6513 - accuracy: 0.7762 - val_loss: 0.7414 - val_accuracy: 0.7401
# Epoch 5/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.8159
# Epoch 00005: val_loss improved from 0.74137 to 0.71597, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.5374 - accuracy: 0.8160 - val_loss: 0.7160 - val_accuracy: 0.7573
# Epoch 6/400
# 1042/1042 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.8457
# Epoch 00006: val_loss improved from 0.71597 to 0.67895, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.4517 - accuracy: 0.8457 - val_loss: 0.6789 - val_accuracy: 0.7821
# Epoch 7/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.8707
# Epoch 00007: val_loss improved from 0.67895 to 0.59321, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.3739 - accuracy: 0.8707 - val_loss: 0.5932 - val_accuracy: 0.8103
# Epoch 8/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.3075 - accuracy: 0.8929
# Epoch 00008: val_loss did not improve from 0.59321
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.3078 - accuracy: 0.8929 - val_loss: 0.6075 - val_accuracy: 0.8131
# Epoch 9/400
# 1033/1042 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.9097
# Epoch 00009: val_loss improved from 0.59321 to 0.53498, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.2617 - accuracy: 0.9098 - val_loss: 0.5350 - val_accuracy: 0.8457
# Epoch 10/400
# 1038/1042 [============================>.] - ETA: 0s - loss: 0.2143 - accuracy: 0.9245
# Epoch 00010: val_loss improved from 0.53498 to 0.49404, saving model to ../models/CNN\Model_019_3_Best.hdf5
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.2146 - accuracy: 0.9244 - val_loss: 0.4940 - val_accuracy: 0.8539
# Epoch 11/400
# 1031/1042 [============================>.] - ETA: 0s - loss: 0.1840 - accuracy: 0.9371
# Epoch 00011: val_loss did not improve from 0.49404
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1842 - accuracy: 0.9369 - val_loss: 0.6563 - val_accuracy: 0.8217
# Epoch 12/400
# 1039/1042 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.9417
# Epoch 00012: val_loss did not improve from 0.49404
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1696 - accuracy: 0.9416 - val_loss: 0.4993 - val_accuracy: 0.8626
# Epoch 13/400
# 1037/1042 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9492
# Epoch 00013: val_loss did not improve from 0.49404
# 1042/1042 [==============================] - 6s 5ms/step - loss: 0.1483 - accuracy: 0.9491 - val_loss: 0.5726 - val_accuracy: 0.8583
# Epoch 00013: early stopping
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0025 - accuracy: 0.7342
# Score for fold 3: loss of 1.002496600151062; accuracy of 73.42000007629395%
# Wall time: 3min 12s

# %%
ensemble_histories = histories
ensemble_predicts = predicts
ensemble_predicts_ = ensemble_predicts / n_splits
y_pred = np.argmax(ensemble_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      1000
#            1       0.89      0.89      0.89      1000
#            2       0.78      0.64      0.71      1000
#            3       0.68      0.62      0.65      1000
#            4       0.71      0.79      0.75      1000
#            5       0.75      0.71      0.73      1000
#            6       0.84      0.80      0.82      1000
#            7       0.76      0.89      0.82      1000
#            8       0.87      0.87      0.87      1000
#            9       0.83      0.89      0.86      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000

# %% [markdown]
# #### Over sampling with data augumentation

# %%
# %%time

cifar10_labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck']

# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model02 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model02.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

    # get target label num
    y_train_ = y_train_removed[train_index]
    df_train = pd.DataFrame(y_train_, columns=['label'])
    target_index = df_train[df_train['label'] == cifar10_labels.index('dog')].index # bird label
    limit_num = len(target_index)

    # concat nate for over sampling
    train_index_oversampling = np.concatenate([
        # target label
        df_train[df_train['label'] == cifar10_labels.index('bird')].sample(limit_num, random_state=42, replace=True).index.values, # bird
        df_train[df_train['label'] == cifar10_labels.index('deer')].sample(limit_num, random_state=42, replace=True).index.values, # deer
        df_train[df_train['label'] == cifar10_labels.index('truck')].sample(limit_num, random_state=42, replace=True).index.values, # truck
        # other label
        df_train[df_train['label'] == cifar10_labels.index('airplane')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('automobile')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('cat')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('dog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('frog')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('horse')].index.values,
        df_train[df_train['label'] == cifar10_labels.index('ship')].index.values
    ])

    print(f'Target label num is {limit_num}, and total label num is {len(train_index_oversampling)}')
    
    x_train_ = x_train_removed[train_index_oversampling]
    y_train_ = y_train_removed[train_index_oversampling]
    
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_020_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    # create generator
    train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=10,
#         shear_range=0.2,
        horizontal_flip=True,
#         vertical_flip=True,
#         width_shift_range=0.1,
#         height_shift_range=0.1,
        zoom_range=0.1
#         channel_shift_range=0.2
        )

    batch_size = 32
    train_datagenerator = train_datagen.flow(x_train_, y_train_onehot, batch_size)
    valid_datagenerator = ImageDataGenerator().flow(x_valid_, y_valid_onehot, batch_size)

    model02_history = model02.fit_generator(train_datagenerator,
                                  steps_per_epoch=int(len(x_train_)//batch_size),
                                  epochs=400,
                                  validation_data=valid_datagenerator,
                                  validation_steps=int(len(x_valid_)//batch_size),
                                  verbose=1,
                                  shuffle=True,
                                  callbacks=[es_cb, cp_cb])

    # inference
    model02.load_weights(chkpt)
    scores = model02.evaluate(x_test, y_test_onehot)
    print(f'Score for fold {fold_no}: {model02.metrics_names[0]} of {scores[0]}; {model02.metrics_names[1]} of {scores[1]*100}%')
    
    predict = model02.predict(x_test)
    predicts += predict
    
    histories.append(model02_history.history)
    fold_no += 1
# Out:
# Target label num is 3334, and total label num is 33336
# WARNING:tensorflow:From <timed exec>:95: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 1.4317 - accuracy: 0.4835
# Epoch 00001: val_loss improved from inf to 1.21303, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 10s 9ms/step - loss: 1.4306 - accuracy: 0.4838 - val_loss: 1.2130 - val_accuracy: 0.5658
# Epoch 2/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 1.0481 - accuracy: 0.6286
# Epoch 00002: val_loss improved from 1.21303 to 1.09975, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.0474 - accuracy: 0.6288 - val_loss: 1.0998 - val_accuracy: 0.6280
# Epoch 3/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.8645 - accuracy: 0.6978
# Epoch 00003: val_loss improved from 1.09975 to 0.87230, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.8643 - accuracy: 0.6979 - val_loss: 0.8723 - val_accuracy: 0.7047
# Epoch 4/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.7629 - accuracy: 0.7350
# Epoch 00004: val_loss did not improve from 0.87230
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7625 - accuracy: 0.7351 - val_loss: 0.9032 - val_accuracy: 0.6952
# Epoch 5/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.7650
# Epoch 00005: val_loss improved from 0.87230 to 0.75289, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6725 - accuracy: 0.7651 - val_loss: 0.7529 - val_accuracy: 0.7415
# Epoch 6/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.6123 - accuracy: 0.7868
# Epoch 00006: val_loss improved from 0.75289 to 0.68630, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6121 - accuracy: 0.7868 - val_loss: 0.6863 - val_accuracy: 0.7670
# Epoch 7/400
# 1041/1041 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.8031
# Epoch 00007: val_loss improved from 0.68630 to 0.63228, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5655 - accuracy: 0.8031 - val_loss: 0.6323 - val_accuracy: 0.7827
# Epoch 8/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.5191 - accuracy: 0.8190
# Epoch 00008: val_loss did not improve from 0.63228
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5189 - accuracy: 0.8192 - val_loss: 0.8041 - val_accuracy: 0.7423
# Epoch 9/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.4839 - accuracy: 0.8323
# Epoch 00009: val_loss did not improve from 0.63228
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4846 - accuracy: 0.8322 - val_loss: 0.6774 - val_accuracy: 0.7796
# Epoch 10/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.4506 - accuracy: 0.8434
# Epoch 00010: val_loss improved from 0.63228 to 0.47253, saving model to ../models/CNN\Model_020_1_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4505 - accuracy: 0.8435 - val_loss: 0.4725 - val_accuracy: 0.8399
# Epoch 11/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.4239 - accuracy: 0.8531
# Epoch 00011: val_loss did not improve from 0.47253
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4242 - accuracy: 0.8530 - val_loss: 0.5848 - val_accuracy: 0.8149
# Epoch 12/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.4008 - accuracy: 0.8616
# Epoch 00012: val_loss did not improve from 0.47253
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4008 - accuracy: 0.8615 - val_loss: 0.4961 - val_accuracy: 0.8384
# Epoch 13/400
# 1041/1041 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8668
# Epoch 00013: val_loss did not improve from 0.47253
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3792 - accuracy: 0.8668 - val_loss: 0.5020 - val_accuracy: 0.8389
# Epoch 00013: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7359 - accuracy: 0.7601
# Score for fold 1: loss of 0.7358883023262024; accuracy of 76.010000705719%
# Target label num is 3333, and total label num is 33331
# Epoch 1/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 1.4313 - accuracy: 0.4842
# Epoch 00001: val_loss improved from inf to 1.87256, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.4309 - accuracy: 0.4844 - val_loss: 1.8726 - val_accuracy: 0.4335
# Epoch 2/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 1.0483 - accuracy: 0.6273
# Epoch 00002: val_loss improved from 1.87256 to 1.03347, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.0483 - accuracy: 0.6273 - val_loss: 1.0335 - val_accuracy: 0.6388
# Epoch 3/400
# 1041/1041 [==============================] - ETA: 0s - loss: 0.8741 - accuracy: 0.6930
# Epoch 00003: val_loss improved from 1.03347 to 0.86877, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.8741 - accuracy: 0.6930 - val_loss: 0.8688 - val_accuracy: 0.7093
# Epoch 4/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.7626 - accuracy: 0.7345
# Epoch 00004: val_loss did not improve from 0.86877
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7632 - accuracy: 0.7343 - val_loss: 1.0172 - val_accuracy: 0.6637
# Epoch 5/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.6779 - accuracy: 0.7637
# Epoch 00005: val_loss improved from 0.86877 to 0.71903, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6781 - accuracy: 0.7637 - val_loss: 0.7190 - val_accuracy: 0.7622
# Epoch 6/400
# 1041/1041 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.7839
# Epoch 00006: val_loss improved from 0.71903 to 0.63450, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6227 - accuracy: 0.7839 - val_loss: 0.6345 - val_accuracy: 0.7817
# Epoch 7/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.5677 - accuracy: 0.8043
# Epoch 00007: val_loss improved from 0.63450 to 0.56003, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5685 - accuracy: 0.8042 - val_loss: 0.5600 - val_accuracy: 0.8108
# Epoch 8/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.5256 - accuracy: 0.8195
# Epoch 00008: val_loss improved from 0.56003 to 0.55870, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5256 - accuracy: 0.8193 - val_loss: 0.5587 - val_accuracy: 0.8143
# Epoch 9/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.8323
# Epoch 00009: val_loss did not improve from 0.55870
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4845 - accuracy: 0.8323 - val_loss: 0.8371 - val_accuracy: 0.7346
# Epoch 10/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.4553 - accuracy: 0.8434
# Epoch 00010: val_loss did not improve from 0.55870
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4551 - accuracy: 0.8434 - val_loss: 0.6352 - val_accuracy: 0.7957
# Epoch 11/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.4207 - accuracy: 0.8539
# Epoch 00011: val_loss improved from 0.55870 to 0.52194, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.4208 - accuracy: 0.8538 - val_loss: 0.5219 - val_accuracy: 0.8294
# Epoch 12/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.3987 - accuracy: 0.8629
# Epoch 00012: val_loss improved from 0.52194 to 0.50864, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3985 - accuracy: 0.8629 - val_loss: 0.5086 - val_accuracy: 0.8299
# Epoch 13/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.8697
# Epoch 00013: val_loss did not improve from 0.50864
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3737 - accuracy: 0.8697 - val_loss: 0.5204 - val_accuracy: 0.8350
# Epoch 14/400
# 1036/1041 [============================>.] - ETA: 0s - loss: 0.3563 - accuracy: 0.8759
# Epoch 00014: val_loss improved from 0.50864 to 0.42081, saving model to ../models/CNN\Model_020_2_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3561 - accuracy: 0.8760 - val_loss: 0.4208 - val_accuracy: 0.8616
# Epoch 15/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.3345 - accuracy: 0.8833
# Epoch 00015: val_loss did not improve from 0.42081
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3348 - accuracy: 0.8832 - val_loss: 0.5214 - val_accuracy: 0.8329
# Epoch 16/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.8857
# Epoch 00016: val_loss did not improve from 0.42081
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3240 - accuracy: 0.8859 - val_loss: 0.4355 - val_accuracy: 0.8616
# Epoch 17/400
# 1038/1041 [============================>.] - ETA: 0s - loss: 0.3070 - accuracy: 0.8927
# Epoch 00017: val_loss did not improve from 0.42081
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.3071 - accuracy: 0.8926 - val_loss: 0.4436 - val_accuracy: 0.8610
# Epoch 00017: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7099 - accuracy: 0.7787
# Score for fold 2: loss of 0.7098930478096008; accuracy of 77.86999940872192%
# Target label num is 3333, and total label num is 33333
# Epoch 1/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 1.4463 - accuracy: 0.4786
# Epoch 00001: val_loss improved from inf to 1.48288, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.4463 - accuracy: 0.4786 - val_loss: 1.4829 - val_accuracy: 0.5015
# Epoch 2/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 1.0789 - accuracy: 0.6178
# Epoch 00002: val_loss improved from 1.48288 to 0.99632, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 1.0786 - accuracy: 0.6180 - val_loss: 0.9963 - val_accuracy: 0.6514
# Epoch 3/400
# 1040/1041 [============================>.] - ETA: 0s - loss: 0.8948 - accuracy: 0.6851
# Epoch 00003: val_loss improved from 0.99632 to 0.92539, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.8948 - accuracy: 0.6851 - val_loss: 0.9254 - val_accuracy: 0.6748
# Epoch 4/400
# 1037/1041 [============================>.] - ETA: 0s - loss: 0.7704 - accuracy: 0.7294
# Epoch 00004: val_loss improved from 0.92539 to 0.74870, saving model to ../models/CNN\Model_020_3_Best.hdf5
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.7704 - accuracy: 0.7295 - val_loss: 0.7487 - val_accuracy: 0.7393
# Epoch 5/400
# 1035/1041 [============================>.] - ETA: 0s - loss: 0.6946 - accuracy: 0.7608
# Epoch 00005: val_loss did not improve from 0.74870
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6944 - accuracy: 0.7607 - val_loss: 1.0454 - val_accuracy: 0.6652
# Epoch 6/400
# 1039/1041 [============================>.] - ETA: 0s - loss: 0.6313 - accuracy: 0.7827
# Epoch 00006: val_loss did not improve from 0.74870
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.6312 - accuracy: 0.7827 - val_loss: 0.8369 - val_accuracy: 0.7255
# Epoch 7/400
# 1038/1041 [============================>.] - ETA: 0s - loss: 0.5715 - accuracy: 0.8004
# Epoch 00007: val_loss did not improve from 0.74870
# 1041/1041 [==============================] - 9s 9ms/step - loss: 0.5717 - accuracy: 0.8004 - val_loss: 1.0746 - val_accuracy: 0.6725
# Epoch 00007: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9219 - accuracy: 0.6854
# Score for fold 3: loss of 0.9218517541885376; accuracy of 68.54000091552734%
# Wall time: 5min 55s

# %%
ensemble_dataaug_histories = histories
ensemble_dataaug_predicts = predicts
ensemble_dataaug_predicts_ = ensemble_dataaug_predicts / n_splits
y_pred = np.argmax(ensemble_dataaug_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.78      1000
#            1       0.82      0.93      0.87      1000
#            2       0.75      0.64      0.69      1000
#            3       0.75      0.48      0.59      1000
#            4       0.82      0.69      0.75      1000
#            5       0.68      0.79      0.73      1000
#            6       0.71      0.89      0.79      1000
#            7       0.80      0.85      0.83      1000
#            8       0.91      0.82      0.86      1000
#            9       0.83      0.87      0.85      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.77     10000
# weighted avg       0.78      0.78      0.77     10000
