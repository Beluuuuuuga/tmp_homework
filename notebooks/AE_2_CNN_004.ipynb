# %% [markdown]
# # Install library

# %%
import os
import random

import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import KFold, StratifiedKFold

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def set_randvalue(value):
    # Set a seed value
    seed_value= value 
    # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
    os.environ['PYTHONHASHSEED']=str(seed_value)
    # 2. Set `python` built-in pseudo-random generator at a fixed value
    random.seed(seed_value)
    # 3. Set `numpy` pseudo-random generator at a fixed value
    np.random.seed(seed_value)
    # 4. Set `tensorflow` pseudo-random generator at a fixed value
    tf.random.set_seed(seed_value)

set_randvalue(42)

# %% [markdown]
# ## Dataset preprocessing and EDA

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # load data
x_train,x_test = x_train.astype('float32')/255.0,x_test.astype('float32')/255.0 # normalization

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# #### Limit three class preprocessing

# %%
# No method on keras to get cifar10 category label name by categoly label?
cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])

bird_num = np.where(cifar10_labels=='bird')
deer_num = np.where(cifar10_labels=='deer')
truck_num = np.where(cifar10_labels=='truck')

limit_num = 2500

# get limit label indexes
bird_indexes = [i for i, label in enumerate(y_train) if label == bird_num]
deer_indexes = [i for i, label in enumerate(y_train) if label == deer_num] 
truck_indexes = [i for i, label in enumerate(y_train) if label == truck_num] 
other_indexes = [i for i, label in enumerate(y_train) if label not in [bird_num, deer_num, truck_num]]

# limit
bird_indexes = bird_indexes[:limit_num]
deer_indexes = deer_indexes[:limit_num]
truck_indexes = truck_indexes[:limit_num]
print(f'Bird label num is {len(bird_indexes)}') # 2500
print(f'Deer label num is {len(deer_indexes)}') # 2500
print(f'Truck label num is {len(truck_indexes)}') # 2500
print(f'Other label num is {len(other_indexes)}') # 35000; 5000*7

# merge and sort
merge_indexes = np.concatenate([other_indexes, bird_indexes, deer_indexes, truck_indexes], 0)
merge_indexes.sort()
print(f'Train label num is {len(merge_indexes)}') # 42500

# create three labels removed train data
x_train_removed =  np.zeros((len(merge_indexes), 32, 32, 3))
y_train_removed =  np.zeros(len(merge_indexes))

for i, train_index in enumerate(merge_indexes):
    x_train_removed[i] = x_train[train_index]
    y_train_removed[i] = y_train[train_index]
    
print(x_train_removed.shape)
print(y_train_removed.shape)
# Out:
# Bird label num is 2500
# Deer label num is 2500
# Truck label num is 2500
# Other label num is 35000
# Train label num is 42500
# (42500, 32, 32, 3)
# (42500,)

# %%
print(x_train_removed.shape)
print(y_train_removed.shape)
del x_train
del y_train
# Out:
# (42500, 32, 32, 3)
# (42500,)

# %%
df = pd.DataFrame(y_train_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    5000
# 7.0    5000
# 6.0    5000
# 5.0    5000
# 3.0    5000
# 1.0    5000
# 0.0    5000
# 9.0    2500
# 4.0    2500
# 2.0    2500
# dtype: int64

# %%
import matplotlib.pyplot as plt

# plot data labels
plt.hist(y_train_removed.flatten())
# Out:
# (array([5000., 5000., 2500., 5000., 2500., 5000., 5000., 5000., 5000.,
#         2500.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## AutoEncoder

# %% [markdown]
# #### Load AE models weight

# %%
# Batch Norm Model
def create_AE01_model(k_size):
    input_img = Input(shape=(32, 32, 3))  # 0
    conv1 = Conv2D(64, (k_size, k_size), padding='same', name="Dense_AE01_1")(input_img) # 1
    conv1 = BatchNormalization(name="BN_AE01_1")(conv1) # 2
    conv1 = Activation('relu', name="Relu_AE01_1")(conv1) # 3
        
    decoded = Conv2D(3, (k_size, k_size), padding='same', name="Dense_AE01_2")(conv1) # 4
    decoded = BatchNormalization(name="BN_AE01_2")(decoded) # 5
    decoded = Activation('relu', name="Relu_AE01_2")(decoded) # 6
    return Model(input_img, decoded)

class AE01():
    def __init__(self, ksize, optimizer):
        self.optimizer = optimizer
        
        self.autoencoder = create_AE01_model(ksize)
        self.encoder = None

    def compile(self, optimizer='adam', loss='binary_crossentropy'):
        self.autoencoder.compile(optimizer=self.optimizer, loss=loss)

    def train(self, x_train=None, x_test=None, epochs=1, batch_size=32, shuffle=True):
        es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
        ae_model_path = '../models/AE/AE01_AE_Best.hdf5'
        cp_cb = ModelCheckpoint(filepath = ae_model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
       
        history = self.autoencoder.fit(x_train, x_train,
                             epochs=epochs,
                             batch_size=batch_size,
                             shuffle=shuffle,
                             callbacks=[es_cb, cp_cb],
                             validation_data=(x_test, x_test))
        
        self.autoencoder.load_weights(ae_model_path)
        
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        encode_model_path = '../models/AE/AE01_Encoder_Best.hdf5'
        self.encoder.save(encode_model_path)
        return history
    
    def load_weights(self, ae_model_path, encode_model_path):
        self.autoencoder.load_weights(ae_model_path)
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        self.encoder.load_weights(encode_model_path)

# %%
ae_ksize = 3
ae_optimizer = 'rmsprop'
stack01 = AE01(ae_ksize, ae_optimizer)
stack01.load_weights('../models/AE/AE01_AE_Best.hdf5', '../models/AE/AE01_Encoder_Best.hdf5')
stack01.encoder.trainable = False
stack01.encoder.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# =================================================================
# Total params: 2,048
# Trainable params: 0
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ## Train

# %% [markdown]
# #### Create Model AE to CNN

# %%
def create_StackedAE01_CNN01_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(output)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 16,16,64
    
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 8,8,128
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    y = Dense(10,activation = "softmax")(x)

    return Model(input_img, y)

# %% [markdown]
# #### Train without data augumentation

# %%
# %%time

# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))
cv_acc = 0
cv_f1 = 0 

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model01 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model01.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

    x_train_ = x_train_removed[train_index]
    y_train_ = y_train_removed[train_index]
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_007_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    model01_history = model01.fit(x_train_, y_train_onehot,
                          batch_size=32,
                          epochs=400,
                          verbose=1,
                          validation_data=(x_valid_, y_valid_onehot),
                          callbacks=[es_cb, cp_cb],
                          shuffle=True)
    
    # inference
    model01.load_weights(chkpt)
    scores = model01.evaluate(x_valid_, y_valid_onehot)
    
    # CV value
    cv_acc += scores[1]*100
    y_valid_pred =  model01.predict(x_valid_)
    y_valid_pred = np.argmax(y_valid_pred, axis=1)
    cv_f1 += f1_score(y_valid_, y_valid_pred, average='macro')*100
    
    print(f'Score for fold {fold_no}: {model01.metrics_names[0]} of {scores[0]}; {model01.metrics_names[1]} of {scores[1]*100}%')
    
    # oof prediction
    predict = model01.predict(x_test)
    predicts += predict
    
    histories.append(model01_history.history)
    fold_no += 1
# Out:
# Epoch 1/400
# 886/886 [==============================] - ETA: 0s - loss: 1.4127 - accuracy: 0.4943
# Epoch 00001: val_loss improved from inf to 1.21509, saving model to ../models/CNN\Model_007_1_Best.hdf5
# 886/886 [==============================] - 6s 6ms/step - loss: 1.4127 - accuracy: 0.4943 - val_loss: 1.2151 - val_accuracy: 0.5738
# Epoch 2/400
# 883/886 [============================>.] - ETA: 0s - loss: 1.0478 - accuracy: 0.6301
# Epoch 00002: val_loss improved from 1.21509 to 1.14171, saving model to ../models/CNN\Model_007_1_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 1.0472 - accuracy: 0.6303 - val_loss: 1.1417 - val_accuracy: 0.5958
# Epoch 3/400
# 879/886 [============================>.] - ETA: 0s - loss: 0.8606 - accuracy: 0.7002
# Epoch 00003: val_loss improved from 1.14171 to 0.86189, saving model to ../models/CNN\Model_007_1_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 0.8602 - accuracy: 0.7003 - val_loss: 0.8619 - val_accuracy: 0.6956
# Epoch 4/400
# 885/886 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.7429
# Epoch 00004: val_loss did not improve from 0.86189
# 886/886 [==============================] - 5s 6ms/step - loss: 0.7277 - accuracy: 0.7429 - val_loss: 0.9626 - val_accuracy: 0.6830
# Epoch 5/400
# 883/886 [============================>.] - ETA: 0s - loss: 0.6264 - accuracy: 0.7787
# Epoch 00005: val_loss did not improve from 0.86189
# 886/886 [==============================] - 5s 6ms/step - loss: 0.6262 - accuracy: 0.7788 - val_loss: 1.0084 - val_accuracy: 0.6743
# Epoch 6/400
# 883/886 [============================>.] - ETA: 0s - loss: 0.5385 - accuracy: 0.8125
# Epoch 00006: val_loss did not improve from 0.86189
# 886/886 [==============================] - 5s 6ms/step - loss: 0.5388 - accuracy: 0.8124 - val_loss: 0.9534 - val_accuracy: 0.6870
# Epoch 00006: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.8619 - accuracy: 0.6956
# Score for fold 1: loss of 0.8618863224983215; accuracy of 69.5630669593811%
# Epoch 1/400
# 878/886 [============================>.] - ETA: 0s - loss: 1.3997 - accuracy: 0.5027
# Epoch 00001: val_loss improved from inf to 1.22447, saving model to ../models/CNN\Model_007_2_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 1.3976 - accuracy: 0.5036 - val_loss: 1.2245 - val_accuracy: 0.5607
# Epoch 2/400
# 875/886 [============================>.] - ETA: 0s - loss: 1.0288 - accuracy: 0.6398
# Epoch 00002: val_loss improved from 1.22447 to 0.97500, saving model to ../models/CNN\Model_007_2_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 1.0282 - accuracy: 0.6401 - val_loss: 0.9750 - val_accuracy: 0.6581
# Epoch 3/400
# 880/886 [============================>.] - ETA: 0s - loss: 0.8315 - accuracy: 0.7104
# Epoch 00003: val_loss did not improve from 0.97500
# 886/886 [==============================] - 5s 6ms/step - loss: 0.8312 - accuracy: 0.7103 - val_loss: 1.1233 - val_accuracy: 0.6195
# Epoch 4/400
# 880/886 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.7516
# Epoch 00004: val_loss improved from 0.97500 to 0.83755, saving model to ../models/CNN\Model_007_2_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 0.7111 - accuracy: 0.7520 - val_loss: 0.8375 - val_accuracy: 0.7056
# Epoch 5/400
# 884/886 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.7844
# Epoch 00005: val_loss did not improve from 0.83755
# 886/886 [==============================] - 5s 6ms/step - loss: 0.6146 - accuracy: 0.7844 - val_loss: 0.9339 - val_accuracy: 0.7057
# Epoch 6/400
# 879/886 [============================>.] - ETA: 0s - loss: 0.5256 - accuracy: 0.8151
# Epoch 00006: val_loss did not improve from 0.83755
# 886/886 [==============================] - 5s 6ms/step - loss: 0.5254 - accuracy: 0.8151 - val_loss: 0.8406 - val_accuracy: 0.7340
# Epoch 7/400
# 880/886 [============================>.] - ETA: 0s - loss: 0.4510 - accuracy: 0.8407
# Epoch 00007: val_loss did not improve from 0.83755
# 886/886 [==============================] - 5s 6ms/step - loss: 0.4519 - accuracy: 0.8404 - val_loss: 0.9128 - val_accuracy: 0.7176
# Epoch 00007: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.8375 - accuracy: 0.7056
# Score for fold 2: loss of 0.8375493288040161; accuracy of 70.5583393573761%
# Epoch 1/400
# 886/886 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.5024
# Epoch 00001: val_loss improved from inf to 1.64138, saving model to ../models/CNN\Model_007_3_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 1.4021 - accuracy: 0.5024 - val_loss: 1.6414 - val_accuracy: 0.4654
# Epoch 2/400
# 877/886 [============================>.] - ETA: 0s - loss: 1.0257 - accuracy: 0.6384
# Epoch 00002: val_loss improved from 1.64138 to 1.10851, saving model to ../models/CNN\Model_007_3_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 1.0246 - accuracy: 0.6388 - val_loss: 1.1085 - val_accuracy: 0.6172
# Epoch 3/400
# 885/886 [============================>.] - ETA: 0s - loss: 0.8578 - accuracy: 0.6997
# Epoch 00003: val_loss improved from 1.10851 to 0.84634, saving model to ../models/CNN\Model_007_3_Best.hdf5
# 886/886 [==============================] - 5s 6ms/step - loss: 0.8577 - accuracy: 0.6997 - val_loss: 0.8463 - val_accuracy: 0.7013
# Epoch 4/400
# 878/886 [============================>.] - ETA: 0s - loss: 0.7272 - accuracy: 0.7438
# Epoch 00004: val_loss did not improve from 0.84634
# 886/886 [==============================] - 5s 6ms/step - loss: 0.7270 - accuracy: 0.7438 - val_loss: 0.8716 - val_accuracy: 0.7016
# Epoch 5/400
# 879/886 [============================>.] - ETA: 0s - loss: 0.6242 - accuracy: 0.7798
# Epoch 00005: val_loss did not improve from 0.84634
# 886/886 [==============================] - 5s 6ms/step - loss: 0.6249 - accuracy: 0.7795 - val_loss: 0.8717 - val_accuracy: 0.7126
# Epoch 6/400
# 883/886 [============================>.] - ETA: 0s - loss: 0.5336 - accuracy: 0.8130
# Epoch 00006: val_loss did not improve from 0.84634
# 886/886 [==============================] - 5s 6ms/step - loss: 0.5338 - accuracy: 0.8131 - val_loss: 0.9271 - val_accuracy: 0.7028
# Epoch 00006: early stopping
# 443/443 [==============================] - 1s 2ms/step - loss: 0.8463 - accuracy: 0.7013
# Score for fold 3: loss of 0.8463360071182251; accuracy of 70.1256513595581%
# Wall time: 1min 48s

# %%
ensemble_histories = histories
ensemble_predicts = predicts
ensemble_predicts_ = ensemble_predicts / n_splits
y_pred = np.argmax(ensemble_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1000
#            1       0.79      0.95      0.86      1000
#            2       0.84      0.49      0.62      1000
#            3       0.56      0.71      0.63      1000
#            4       0.81      0.68      0.74      1000
#            5       0.78      0.70      0.74      1000
#            6       0.82      0.84      0.83      1000
#            7       0.78      0.88      0.83      1000
#            8       0.87      0.91      0.89      1000
#            9       0.91      0.78      0.84      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.79      0.78      0.78     10000
# weighted avg       0.79      0.78      0.78     10000

# %%
print(f'CV ACC is {cv_acc//n_splits},n_splits CV macro F1 is {cv_f1//n_splits}')
# Out:
# CV ACC is 70.0,n_splits CV macro F1 is 68.0

# %% [markdown]
# #### Train with data augumentation 1

# %%
# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))
cv_acc = 0
cv_f1 = 0 

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model02 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model02.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

    x_train_ = x_train_removed[train_index]
    y_train_ = y_train_removed[train_index]
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_008_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    # create generator
    train_datagen = ImageDataGenerator(
#     rescale=1./255,
    rotation_range=10,
    shear_range=0.2,
    horizontal_flip=True,
#     vertical_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
#     channel_shift_range=0.2
    )

    batch_size = 32
    train_datagenerator = train_datagen.flow(x_train_, y_train_onehot, batch_size)
    valid_datagenerator = ImageDataGenerator().flow(x_valid_, y_valid_onehot, batch_size)

    model02_history = model02.fit_generator(train_datagenerator,
                                  steps_per_epoch=int(len(x_train_)//batch_size),
                                  epochs=400,
                                  validation_data=valid_datagenerator,
                                  validation_steps=int(len(x_valid_)//batch_size),
                                  verbose=1,
                                  shuffle=True,
                                  callbacks=[es_cb, cp_cb])

    # inference
    model02.load_weights(chkpt)
    scores = model02.evaluate(x_valid_, y_valid_onehot)
    
    # CV value
    cv_acc += scores[1]*100
    y_valid_pred =  model02.predict(x_valid_)
    y_valid_pred = np.argmax(y_valid_pred, axis=1)
    cv_f1 += f1_score(y_valid_, y_valid_pred, average='macro')*100
    
    print(f'Score for fold {fold_no}: {model02.metrics_names[0]} of {scores[0]}; {model02.metrics_names[1]} of {scores[1]*100}%')
    
    # oof prediction
    predict = model02.predict(x_test)
    predicts += predict
    
    histories.append(model02_history.history)
    fold_no += 1
# Out:
# WARNING:tensorflow:From <ipython-input-15-b9fdee0183df>:60: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/400
# 882/885 [============================>.] - ETA: 0s - loss: 1.4845 - accuracy: 0.4721
# Epoch 00001: val_loss improved from inf to 1.38918, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 11s 12ms/step - loss: 1.4841 - accuracy: 0.4723 - val_loss: 1.3892 - val_accuracy: 0.5061
# Epoch 2/400
# 882/885 [============================>.] - ETA: 0s - loss: 1.1648 - accuracy: 0.5901
# Epoch 00002: val_loss improved from 1.38918 to 1.17657, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 11s 12ms/step - loss: 1.1643 - accuracy: 0.5903 - val_loss: 1.1766 - val_accuracy: 0.5699
# Epoch 3/400
# 884/885 [============================>.] - ETA: 0s - loss: 1.0104 - accuracy: 0.6425
# Epoch 00003: val_loss did not improve from 1.17657
# 885/885 [==============================] - 10s 11ms/step - loss: 1.0107 - accuracy: 0.6423 - val_loss: 1.1824 - val_accuracy: 0.5989
# Epoch 4/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.9135 - accuracy: 0.6796
# Epoch 00004: val_loss improved from 1.17657 to 0.97206, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.9130 - accuracy: 0.6799 - val_loss: 0.9721 - val_accuracy: 0.6640
# Epoch 5/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.8437 - accuracy: 0.7048
# Epoch 00005: val_loss improved from 0.97206 to 0.80365, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.8446 - accuracy: 0.7047 - val_loss: 0.8037 - val_accuracy: 0.7222
# Epoch 6/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.7874 - accuracy: 0.7247
# Epoch 00006: val_loss improved from 0.80365 to 0.75518, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7871 - accuracy: 0.7247 - val_loss: 0.7552 - val_accuracy: 0.7364
# Epoch 7/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.7284 - accuracy: 0.7468
# Epoch 00007: val_loss improved from 0.75518 to 0.75501, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7284 - accuracy: 0.7468 - val_loss: 0.7550 - val_accuracy: 0.7375
# Epoch 8/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.6938 - accuracy: 0.7575
# Epoch 00008: val_loss improved from 0.75501 to 0.72039, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6933 - accuracy: 0.7576 - val_loss: 0.7204 - val_accuracy: 0.7530
# Epoch 9/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.6624 - accuracy: 0.7680
# Epoch 00009: val_loss did not improve from 0.72039
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6624 - accuracy: 0.7679 - val_loss: 0.7641 - val_accuracy: 0.7519
# Epoch 10/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.7770
# Epoch 00010: val_loss improved from 0.72039 to 0.66178, saving model to ../models/CNN\Model_008_1_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6350 - accuracy: 0.7770 - val_loss: 0.6618 - val_accuracy: 0.7750
# Epoch 11/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.6060 - accuracy: 0.7906
# Epoch 00011: val_loss did not improve from 0.66178
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6056 - accuracy: 0.7907 - val_loss: 0.7069 - val_accuracy: 0.7702
# Epoch 12/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.5775 - accuracy: 0.8002
# Epoch 00012: val_loss did not improve from 0.66178
# 885/885 [==============================] - 10s 11ms/step - loss: 0.5775 - accuracy: 0.8001 - val_loss: 0.7508 - val_accuracy: 0.7575
# Epoch 13/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.5620 - accuracy: 0.8043
# Epoch 00013: val_loss did not improve from 0.66178
# 885/885 [==============================] - 10s 11ms/step - loss: 0.5617 - accuracy: 0.8044 - val_loss: 0.9657 - val_accuracy: 0.7060
# Epoch 00013: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6611 - accuracy: 0.7750
# Score for fold 1: loss of 0.6611487865447998; accuracy of 77.50405669212341%
# Epoch 1/400
# 882/885 [============================>.] - ETA: 0s - loss: 1.4946 - accuracy: 0.4691
# Epoch 00001: val_loss improved from inf to 2.15008, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 1.4937 - accuracy: 0.4694 - val_loss: 2.1501 - val_accuracy: 0.3761
# Epoch 2/400
# 883/885 [============================>.] - ETA: 0s - loss: 1.1784 - accuracy: 0.5822
# Epoch 00002: val_loss improved from 2.15008 to 1.07390, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 1.1777 - accuracy: 0.5826 - val_loss: 1.0739 - val_accuracy: 0.6263
# Epoch 3/400
# 884/885 [============================>.] - ETA: 0s - loss: 1.0133 - accuracy: 0.6436
# Epoch 00003: val_loss improved from 1.07390 to 0.98535, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 1.0128 - accuracy: 0.6438 - val_loss: 0.9853 - val_accuracy: 0.6628
# Epoch 4/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.8958 - accuracy: 0.6823
# Epoch 00004: val_loss improved from 0.98535 to 0.85450, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.8959 - accuracy: 0.6822 - val_loss: 0.8545 - val_accuracy: 0.7101
# Epoch 5/400
# 885/885 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.7118
# Epoch 00005: val_loss improved from 0.85450 to 0.84944, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.8235 - accuracy: 0.7118 - val_loss: 0.8494 - val_accuracy: 0.7095
# Epoch 6/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.7721 - accuracy: 0.7304
# Epoch 00006: val_loss improved from 0.84944 to 0.79974, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7720 - accuracy: 0.7304 - val_loss: 0.7997 - val_accuracy: 0.7312
# Epoch 7/400
# 885/885 [==============================] - ETA: 0s - loss: 0.7183 - accuracy: 0.7518
# Epoch 00007: val_loss did not improve from 0.79974
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7183 - accuracy: 0.7518 - val_loss: 0.9857 - val_accuracy: 0.6994
# Epoch 8/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.6778 - accuracy: 0.7642
# Epoch 00008: val_loss did not improve from 0.79974
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6780 - accuracy: 0.7641 - val_loss: 0.9900 - val_accuracy: 0.7011
# Epoch 9/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.6451 - accuracy: 0.7745
# Epoch 00009: val_loss improved from 0.79974 to 0.71640, saving model to ../models/CNN\Model_008_2_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6457 - accuracy: 0.7744 - val_loss: 0.7164 - val_accuracy: 0.7619
# Epoch 10/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.6135 - accuracy: 0.7833
# Epoch 00010: val_loss did not improve from 0.71640
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6129 - accuracy: 0.7835 - val_loss: 0.7643 - val_accuracy: 0.7578
# Epoch 11/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.5918 - accuracy: 0.7944
# Epoch 00011: val_loss did not improve from 0.71640
# 885/885 [==============================] - 10s 11ms/step - loss: 0.5920 - accuracy: 0.7943 - val_loss: 0.7918 - val_accuracy: 0.7534
# Epoch 12/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.5675 - accuracy: 0.8018
# Epoch 00012: val_loss did not improve from 0.71640
# 885/885 [==============================] - 10s 11ms/step - loss: 0.5674 - accuracy: 0.8017 - val_loss: 0.7209 - val_accuracy: 0.7595
# Epoch 00012: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.7161 - accuracy: 0.7618
# Score for fold 2: loss of 0.7161350846290588; accuracy of 76.18408799171448%
# Epoch 1/400
# 882/885 [============================>.] - ETA: 0s - loss: 1.4915 - accuracy: 0.4702
# Epoch 00001: val_loss improved from inf to 1.25531, saving model to ../models/CNN\Model_008_3_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 1.4902 - accuracy: 0.4707 - val_loss: 1.2553 - val_accuracy: 0.5650
# Epoch 2/400
# 882/885 [============================>.] - ETA: 0s - loss: 1.1643 - accuracy: 0.5873
# Epoch 00002: val_loss did not improve from 1.25531
# 885/885 [==============================] - 10s 11ms/step - loss: 1.1643 - accuracy: 0.5874 - val_loss: 1.4098 - val_accuracy: 0.5513
# Epoch 3/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.9984 - accuracy: 0.6497
# Epoch 00003: val_loss improved from 1.25531 to 1.09813, saving model to ../models/CNN\Model_008_3_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.9986 - accuracy: 0.6497 - val_loss: 1.0981 - val_accuracy: 0.6310
# Epoch 4/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.8983 - accuracy: 0.6833
# Epoch 00004: val_loss did not improve from 1.09813
# 885/885 [==============================] - 10s 11ms/step - loss: 0.8987 - accuracy: 0.6832 - val_loss: 1.2859 - val_accuracy: 0.6198
# Epoch 5/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.8210 - accuracy: 0.7155
# Epoch 00005: val_loss improved from 1.09813 to 1.01463, saving model to ../models/CNN\Model_008_3_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.8216 - accuracy: 0.7151 - val_loss: 1.0146 - val_accuracy: 0.6772
# Epoch 6/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.7595 - accuracy: 0.7321
# Epoch 00006: val_loss improved from 1.01463 to 0.80173, saving model to ../models/CNN\Model_008_3_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7593 - accuracy: 0.7322 - val_loss: 0.8017 - val_accuracy: 0.7280
# Epoch 7/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.7195 - accuracy: 0.7488
# Epoch 00007: val_loss improved from 0.80173 to 0.73211, saving model to ../models/CNN\Model_008_3_Best.hdf5
# 885/885 [==============================] - 10s 11ms/step - loss: 0.7193 - accuracy: 0.7490 - val_loss: 0.7321 - val_accuracy: 0.7524
# Epoch 8/400
# 885/885 [==============================] - ETA: 0s - loss: 0.6776 - accuracy: 0.7590
# Epoch 00008: val_loss did not improve from 0.73211
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6776 - accuracy: 0.7590 - val_loss: 0.7711 - val_accuracy: 0.7475
# Epoch 9/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.6467 - accuracy: 0.7748
# Epoch 00009: val_loss did not improve from 0.73211
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6476 - accuracy: 0.7744 - val_loss: 0.8434 - val_accuracy: 0.7260
# Epoch 10/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.6205 - accuracy: 0.7851
# Epoch 00010: val_loss did not improve from 0.73211
# 885/885 [==============================] - 10s 11ms/step - loss: 0.6203 - accuracy: 0.7852 - val_loss: 0.9233 - val_accuracy: 0.7116
# Epoch 00010: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.7315 - accuracy: 0.7526
# Score for fold 3: loss of 0.7315492630004883; accuracy of 75.25765895843506%

# %%
ensemble_dataaug_histories = histories
ensemble_dataaug_predicts = predicts
ensemble_dataaug_predicts_ = ensemble_dataaug_predicts / n_splits
y_pred = np.argmax(ensemble_dataaug_predicts_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77      1000
#            1       0.81      0.94      0.87      1000
#            2       0.65      0.60      0.62      1000
#            3       0.56      0.70      0.62      1000
#            4       0.78      0.55      0.65      1000
#            5       0.86      0.50      0.64      1000
#            6       0.66      0.88      0.75      1000
#            7       0.77      0.82      0.79      1000
#            8       0.89      0.85      0.87      1000
#            9       0.93      0.75      0.83      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.76      0.74      0.74     10000
# weighted avg       0.76      0.74      0.74     10000

# %%
print(f'CV ACC is {cv_acc//n_splits},n_splits CV macro F1 is {cv_f1//n_splits}')
# Out:
# CV ACC is 76.0,n_splits CV macro F1 is 74.0

# %% [markdown]
# #### Train with data augumentation 2

# %%
# train
saveDir = "../models/CNN/"
histories = []
nb_classes = 10
predicts = np.zeros((10000, 10))
cv_acc = 0
cv_f1 = 0 

# cross validation
# Define the K-fold Cross Validator
n_splits = 3
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
fold_no = 1
for train_index, test_index in kfold.split(x_train_removed, y_train_removed):
    # model instance
    model03 = create_StackedAE01_CNN01_model(stack01.encoder)
    adam = Adam() # defalut
    model03.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

    x_train_ = x_train_removed[train_index]
    y_train_ = y_train_removed[train_index]
    x_valid_ = x_train_removed[test_index]
    y_valid_ = y_train_removed[test_index]

    # one hot encoding
    y_train_onehot = to_categorical(y_train_, nb_classes)
    y_valid_onehot = to_categorical(y_valid_, nb_classes)
    y_test_onehot = to_categorical(y_test, nb_classes)
    
    # callback
    es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    chkpt = saveDir + 'Model_014_' +  str(fold_no) + '_Best.hdf5'
    cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    # create generator
    train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=10,
#         shear_range=0.2,
        horizontal_flip=True,
#         vertical_flip=True,
#         width_shift_range=0.1,
#         height_shift_range=0.1,
        zoom_range=0.1
#         channel_shift_range=0.2
        )

    batch_size = 32
    train_datagenerator = train_datagen.flow(x_train_, y_train_onehot, batch_size)
    valid_datagenerator = ImageDataGenerator().flow(x_valid_, y_valid_onehot, batch_size)

    model03_history = model03.fit_generator(train_datagenerator,
                                  steps_per_epoch=int(len(x_train_)//batch_size),
                                  epochs=400,
                                  validation_data=valid_datagenerator,
                                  validation_steps=int(len(x_valid_)//batch_size),
                                  verbose=1,
                                  shuffle=True,
                                  callbacks=[es_cb, cp_cb])

    # inference
    model03.load_weights(chkpt)
    scores = model03.evaluate(x_valid_, y_valid_onehot)
    
    # CV value
    cv_acc += scores[1]*100
    y_valid_pred =  model03.predict(x_valid_)
    y_valid_pred = np.argmax(y_valid_pred, axis=1)
    cv_f1 += f1_score(y_valid_, y_valid_pred, average='macro')*100
    
    print(f'Score for fold {fold_no}: {model03.metrics_names[0]} of {scores[0]}; {model03.metrics_names[1]} of {scores[1]*100}%')
    
    # oof prediction
    predict = model03.predict(x_test)
    predicts += predict
    
    histories.append(model03_history.history)
    fold_no += 1
# Out:
# Epoch 1/400
# 880/885 [============================>.] - ETA: 0s - loss: 1.4512 - accuracy: 0.4823
# Epoch 00001: val_loss improved from inf to 1.19552, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 1.4497 - accuracy: 0.4829 - val_loss: 1.1955 - val_accuracy: 0.5773
# Epoch 2/400
# 885/885 [==============================] - ETA: 0s - loss: 1.0884 - accuracy: 0.6103
# Epoch 00002: val_loss did not improve from 1.19552
# 885/885 [==============================] - 8s 9ms/step - loss: 1.0884 - accuracy: 0.6103 - val_loss: 1.2496 - val_accuracy: 0.5873
# Epoch 3/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.9171 - accuracy: 0.6765
# Epoch 00003: val_loss improved from 1.19552 to 1.15100, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.9169 - accuracy: 0.6764 - val_loss: 1.1510 - val_accuracy: 0.6230
# Epoch 4/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.8131 - accuracy: 0.7174
# Epoch 00004: val_loss improved from 1.15100 to 0.85001, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.8130 - accuracy: 0.7175 - val_loss: 0.8500 - val_accuracy: 0.7075
# Epoch 5/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.7372 - accuracy: 0.7443
# Epoch 00005: val_loss did not improve from 0.85001
# 885/885 [==============================] - 8s 9ms/step - loss: 0.7366 - accuracy: 0.7444 - val_loss: 0.9202 - val_accuracy: 0.6905
# Epoch 6/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.6803 - accuracy: 0.7621
# Epoch 00006: val_loss improved from 0.85001 to 0.81743, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6808 - accuracy: 0.7619 - val_loss: 0.8174 - val_accuracy: 0.7279
# Epoch 7/400
# 885/885 [==============================] - ETA: 0s - loss: 0.6267 - accuracy: 0.7831
# Epoch 00007: val_loss did not improve from 0.81743
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6267 - accuracy: 0.7831 - val_loss: 0.8705 - val_accuracy: 0.7195
# Epoch 8/400
# 879/885 [============================>.] - ETA: 0s - loss: 0.5843 - accuracy: 0.7942
# Epoch 00008: val_loss improved from 0.81743 to 0.79405, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5843 - accuracy: 0.7945 - val_loss: 0.7940 - val_accuracy: 0.7291
# Epoch 9/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.8114
# Epoch 00009: val_loss improved from 0.79405 to 0.66234, saving model to ../models/CNN\Model_014_1_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5459 - accuracy: 0.8114 - val_loss: 0.6623 - val_accuracy: 0.7780
# Epoch 10/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.5160 - accuracy: 0.8179
# Epoch 00010: val_loss did not improve from 0.66234
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5163 - accuracy: 0.8178 - val_loss: 0.6881 - val_accuracy: 0.7736
# Epoch 11/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.4813 - accuracy: 0.8325
# Epoch 00011: val_loss did not improve from 0.66234
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4810 - accuracy: 0.8328 - val_loss: 0.7458 - val_accuracy: 0.7643
# Epoch 12/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.4569 - accuracy: 0.8400
# Epoch 00012: val_loss did not improve from 0.66234
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4568 - accuracy: 0.8400 - val_loss: 0.7936 - val_accuracy: 0.7560
# Epoch 00012: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6623 - accuracy: 0.7781
# Score for fold 1: loss of 0.6623304486274719; accuracy of 77.81463861465454%
# Epoch 1/400
# 883/885 [============================>.] - ETA: 0s - loss: 1.4407 - accuracy: 0.4897
# Epoch 00001: val_loss improved from inf to 1.30155, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 1.4403 - accuracy: 0.4899 - val_loss: 1.3015 - val_accuracy: 0.5359
# Epoch 2/400
# 884/885 [============================>.] - ETA: 0s - loss: 1.0894 - accuracy: 0.6156
# Epoch 00002: val_loss improved from 1.30155 to 1.06513, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 1.0892 - accuracy: 0.6156 - val_loss: 1.0651 - val_accuracy: 0.6365
# Epoch 3/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.9434 - accuracy: 0.6691
# Epoch 00003: val_loss improved from 1.06513 to 0.98919, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.9428 - accuracy: 0.6693 - val_loss: 0.9892 - val_accuracy: 0.6595
# Epoch 4/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.8335 - accuracy: 0.7099
# Epoch 00004: val_loss improved from 0.98919 to 0.96823, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.8336 - accuracy: 0.7097 - val_loss: 0.9682 - val_accuracy: 0.6708
# Epoch 5/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.7581 - accuracy: 0.7334
# Epoch 00005: val_loss improved from 0.96823 to 0.91360, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.7582 - accuracy: 0.7334 - val_loss: 0.9136 - val_accuracy: 0.6931
# Epoch 6/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.6910 - accuracy: 0.7559
# Epoch 00006: val_loss improved from 0.91360 to 0.81440, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6910 - accuracy: 0.7560 - val_loss: 0.8144 - val_accuracy: 0.7234
# Epoch 7/400
# 879/885 [============================>.] - ETA: 0s - loss: 0.6365 - accuracy: 0.7784
# Epoch 00007: val_loss improved from 0.81440 to 0.79292, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6361 - accuracy: 0.7784 - val_loss: 0.7929 - val_accuracy: 0.7332
# Epoch 8/400
# 879/885 [============================>.] - ETA: 0s - loss: 0.6020 - accuracy: 0.7881
# Epoch 00008: val_loss improved from 0.79292 to 0.73355, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6023 - accuracy: 0.7879 - val_loss: 0.7336 - val_accuracy: 0.7558
# Epoch 9/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.5572 - accuracy: 0.8032
# Epoch 00009: val_loss did not improve from 0.73355
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5571 - accuracy: 0.8030 - val_loss: 0.8214 - val_accuracy: 0.7441
# Epoch 10/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.5234 - accuracy: 0.8156
# Epoch 00010: val_loss improved from 0.73355 to 0.72881, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5231 - accuracy: 0.8158 - val_loss: 0.7288 - val_accuracy: 0.7630
# Epoch 11/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.4964 - accuracy: 0.8266
# Epoch 00011: val_loss improved from 0.72881 to 0.68220, saving model to ../models/CNN\Model_014_2_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4965 - accuracy: 0.8265 - val_loss: 0.6822 - val_accuracy: 0.7776
# Epoch 12/400
# 885/885 [==============================] - ETA: 0s - loss: 0.4616 - accuracy: 0.8352
# Epoch 00012: val_loss did not improve from 0.68220
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4616 - accuracy: 0.8352 - val_loss: 0.7287 - val_accuracy: 0.7695
# Epoch 13/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.4429 - accuracy: 0.8443
# Epoch 00013: val_loss did not improve from 0.68220
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4429 - accuracy: 0.8444 - val_loss: 0.6939 - val_accuracy: 0.7726
# Epoch 14/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.4184 - accuracy: 0.8533
# Epoch 00014: val_loss did not improve from 0.68220
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4190 - accuracy: 0.8530 - val_loss: 0.7827 - val_accuracy: 0.7606
# Epoch 00014: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6821 - accuracy: 0.7777
# Score for fold 2: loss of 0.6820681691169739; accuracy of 77.77228951454163%
# Epoch 1/400
# 884/885 [============================>.] - ETA: 0s - loss: 1.4472 - accuracy: 0.4871
# Epoch 00001: val_loss improved from inf to 1.42683, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 1.4470 - accuracy: 0.4872 - val_loss: 1.4268 - val_accuracy: 0.4894
# Epoch 2/400
# 885/885 [==============================] - ETA: 0s - loss: 1.0927 - accuracy: 0.6112
# Epoch 00002: val_loss improved from 1.42683 to 1.17737, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 1.0927 - accuracy: 0.6112 - val_loss: 1.1774 - val_accuracy: 0.5913
# Epoch 3/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.9215 - accuracy: 0.6757
# Epoch 00003: val_loss improved from 1.17737 to 0.93769, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.9215 - accuracy: 0.6753 - val_loss: 0.9377 - val_accuracy: 0.6806
# Epoch 4/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.8244 - accuracy: 0.7102
# Epoch 00004: val_loss did not improve from 0.93769
# 885/885 [==============================] - 8s 9ms/step - loss: 0.8236 - accuracy: 0.7105 - val_loss: 1.0704 - val_accuracy: 0.6594
# Epoch 5/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.7455 - accuracy: 0.7388
# Epoch 00005: val_loss improved from 0.93769 to 0.84984, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 9s 10ms/step - loss: 0.7465 - accuracy: 0.7383 - val_loss: 0.8498 - val_accuracy: 0.7044
# Epoch 6/400
# 883/885 [============================>.] - ETA: 0s - loss: 0.6850 - accuracy: 0.7602
# Epoch 00006: val_loss did not improve from 0.84984
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6844 - accuracy: 0.7604 - val_loss: 0.9526 - val_accuracy: 0.7048
# Epoch 7/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.6313 - accuracy: 0.7796
# Epoch 00007: val_loss did not improve from 0.84984
# 885/885 [==============================] - 8s 9ms/step - loss: 0.6311 - accuracy: 0.7797 - val_loss: 0.8540 - val_accuracy: 0.7170
# Epoch 8/400
# 879/885 [============================>.] - ETA: 0s - loss: 0.5918 - accuracy: 0.7905
# Epoch 00008: val_loss improved from 0.84984 to 0.76895, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5912 - accuracy: 0.7907 - val_loss: 0.7689 - val_accuracy: 0.7455
# Epoch 9/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.5454 - accuracy: 0.8103
# Epoch 00009: val_loss improved from 0.76895 to 0.76787, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5459 - accuracy: 0.8103 - val_loss: 0.7679 - val_accuracy: 0.7443
# Epoch 10/400
# 885/885 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8207
# Epoch 00010: val_loss improved from 0.76787 to 0.69353, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.5157 - accuracy: 0.8207 - val_loss: 0.6935 - val_accuracy: 0.7701
# Epoch 11/400
# 881/885 [============================>.] - ETA: 0s - loss: 0.4857 - accuracy: 0.8300
# Epoch 00011: val_loss did not improve from 0.69353
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4860 - accuracy: 0.8299 - val_loss: 0.8155 - val_accuracy: 0.7571
# Epoch 12/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.4567 - accuracy: 0.8397
# Epoch 00012: val_loss did not improve from 0.69353
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4567 - accuracy: 0.8397 - val_loss: 0.7760 - val_accuracy: 0.7546
# Epoch 13/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.4283 - accuracy: 0.8508
# Epoch 00013: val_loss improved from 0.69353 to 0.65789, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4285 - accuracy: 0.8506 - val_loss: 0.6579 - val_accuracy: 0.7854
# Epoch 14/400
# 880/885 [============================>.] - ETA: 0s - loss: 0.4118 - accuracy: 0.8562
# Epoch 00014: val_loss did not improve from 0.65789
# 885/885 [==============================] - 8s 9ms/step - loss: 0.4118 - accuracy: 0.8563 - val_loss: 0.7992 - val_accuracy: 0.7616
# Epoch 15/400
# 879/885 [============================>.] - ETA: 0s - loss: 0.3899 - accuracy: 0.8619
# Epoch 00015: val_loss did not improve from 0.65789
# 885/885 [==============================] - 8s 9ms/step - loss: 0.3909 - accuracy: 0.8616 - val_loss: 0.9056 - val_accuracy: 0.7495
# Epoch 16/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.3641 - accuracy: 0.8700
# Epoch 00016: val_loss improved from 0.65789 to 0.65562, saving model to ../models/CNN\Model_014_3_Best.hdf5
# 885/885 [==============================] - 8s 9ms/step - loss: 0.3640 - accuracy: 0.8700 - val_loss: 0.6556 - val_accuracy: 0.7887
# Epoch 17/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.3615 - accuracy: 0.8729
# Epoch 00017: val_loss did not improve from 0.65562
# 885/885 [==============================] - 8s 9ms/step - loss: 0.3615 - accuracy: 0.8730 - val_loss: 0.8615 - val_accuracy: 0.7487
# Epoch 18/400
# 882/885 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.8808
# Epoch 00018: val_loss did not improve from 0.65562
# 885/885 [==============================] - 8s 9ms/step - loss: 0.3344 - accuracy: 0.8807 - val_loss: 0.8050 - val_accuracy: 0.7698
# Epoch 19/400
# 884/885 [============================>.] - ETA: 0s - loss: 0.3287 - accuracy: 0.8839
# Epoch 00019: val_loss did not improve from 0.65562
# 885/885 [==============================] - 8s 9ms/step - loss: 0.3286 - accuracy: 0.8839 - val_loss: 0.7623 - val_accuracy: 0.7881
# Epoch 00019: early stopping
# 443/443 [==============================] - 1s 3ms/step - loss: 0.6558 - accuracy: 0.7888
# Score for fold 3: loss of 0.6558350920677185; accuracy of 78.87900471687317%

# %%
ensemble_dataaug_histories2 = histories
ensemble_dataaug_predicts2 = predicts
ensemble_dataaug_predicts2_ = ensemble_dataaug_predicts2 / n_splits
y_pred = np.argmax(ensemble_dataaug_predicts2_, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      1000
#            1       0.81      0.96      0.88      1000
#            2       0.75      0.59      0.66      1000
#            3       0.72      0.49      0.58      1000
#            4       0.86      0.52      0.65      1000
#            5       0.63      0.82      0.71      1000
#            6       0.63      0.91      0.75      1000
#            7       0.74      0.86      0.80      1000
#            8       0.86      0.91      0.89      1000
#            9       0.94      0.76      0.84      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.78      0.76      0.76     10000
# weighted avg       0.78      0.76      0.76     10000

# %%
print(f'CV ACC is {cv_acc//n_splits},n_splits CV macro F1 is {cv_f1//n_splits}')
# Out:
# CV ACC is 73.0,n_splits CV macro F1 is 71.0
