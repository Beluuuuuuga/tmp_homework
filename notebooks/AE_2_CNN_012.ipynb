# %% [markdown]
# # Install library

# %%
import os
import random

import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation, Add
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def set_randvalue(value):
    # Set a seed value
    seed_value= value 
    # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
    os.environ['PYTHONHASHSEED']=str(seed_value)
    # 2. Set `python` built-in pseudo-random generator at a fixed value
    random.seed(seed_value)
    # 3. Set `numpy` pseudo-random generator at a fixed value
    np.random.seed(seed_value)
    # 4. Set `tensorflow` pseudo-random generator at a fixed value
    tf.random.set_seed(seed_value)

set_randvalue(42)

# %% [markdown]
# ## Dataset preprocessing and EDA

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # load data
x_train,x_test = x_train.astype('float32')/255.0,x_test.astype('float32')/255.0 # normalization

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# #### Limit three class preprocessing

# %%
# No method on keras to get cifar10 category label name by categoly label?
cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])

bird_num = np.where(cifar10_labels=='bird')
deer_num = np.where(cifar10_labels=='deer')
truck_num = np.where(cifar10_labels=='truck')

limit_num = 2500

# get limit label indexes
bird_indexes = [i for i, label in enumerate(y_train) if label == bird_num]
deer_indexes = [i for i, label in enumerate(y_train) if label == deer_num] 
truck_indexes = [i for i, label in enumerate(y_train) if label == truck_num] 
other_indexes = [i for i, label in enumerate(y_train) if label not in [bird_num, deer_num, truck_num]]

# limit
bird_indexes = bird_indexes[:limit_num]
deer_indexes = deer_indexes[:limit_num]
truck_indexes = truck_indexes[:limit_num]
print(f'Bird label num is {len(bird_indexes)}') # 2500
print(f'Deer label num is {len(deer_indexes)}') # 2500
print(f'Truck label num is {len(truck_indexes)}') # 2500
print(f'Other label num is {len(other_indexes)}') # 35000; 5000*7

# merge and sort
merge_indexes = np.concatenate([other_indexes, bird_indexes, deer_indexes, truck_indexes], 0)
merge_indexes.sort()
print(f'Train label num is {len(merge_indexes)}') # 42500

# create three labels removed train data
x_train_removed =  np.zeros((len(merge_indexes), 32, 32, 3))
y_train_removed =  np.zeros(len(merge_indexes))

for i, train_index in enumerate(merge_indexes):
    x_train_removed[i] = x_train[train_index]
    y_train_removed[i] = y_train[train_index]
    
print(x_train_removed.shape)
print(y_train_removed.shape)
# Out:
# Bird label num is 2500
# Deer label num is 2500
# Truck label num is 2500
# Other label num is 35000
# Train label num is 42500
# (42500, 32, 32, 3)
# (42500,)

# %%
print(x_train_removed.shape)
print(y_train_removed.shape)
del x_train
del y_train
# Out:
# (42500, 32, 32, 3)
# (42500,)

# %%
df = pd.DataFrame(y_train_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    5000
# 7.0    5000
# 6.0    5000
# 5.0    5000
# 3.0    5000
# 1.0    5000
# 0.0    5000
# 9.0    2500
# 4.0    2500
# 2.0    2500
# dtype: int64

# %%
import matplotlib.pyplot as plt

# plot data labels
plt.hist(y_train_removed.flatten())
# Out:
# (array([5000., 5000., 2500., 5000., 2500., 5000., 5000., 5000., 5000.,
#         2500.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
# train test split
# stratify y label
x_train_removed, x_valid_removed, y_train_removed, y_valid_removed = train_test_split(x_train_removed, y_train_removed, 
                                                                      test_size=0.3, random_state=42, stratify=y_train_removed)

# %%
print(x_train_removed.shape)
print(y_train_removed.shape)
print(x_valid_removed.shape)
print(y_valid_removed.shape)
# Out:
# (29750, 32, 32, 3)
# (29750,)
# (12750, 32, 32, 3)
# (12750,)

# %%
df = pd.DataFrame(y_train_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    3500
# 7.0    3500
# 6.0    3500
# 5.0    3500
# 3.0    3500
# 1.0    3500
# 0.0    3500
# 9.0    1750
# 4.0    1750
# 2.0    1750
# dtype: int64

# %%
df = pd.DataFrame(y_valid_removed.flatten())
print(df.value_counts())
del df
# Out:
# 8.0    1500
# 7.0    1500
# 6.0    1500
# 5.0    1500
# 3.0    1500
# 1.0    1500
# 0.0    1500
# 9.0     750
# 4.0     750
# 2.0     750
# dtype: int64

# %% [markdown]
# ## AutoEncoder

# %% [markdown]
# #### Load AE models weight

# %%
# Batch Norm Model
def create_AE01_model(k_size):
    input_img = Input(shape=(32, 32, 3))  # 0
    conv1 = Conv2D(64, (k_size, k_size), padding='same', name="Dense_AE01_1")(input_img) # 1
    conv1 = BatchNormalization(name="BN_AE01_1")(conv1) # 2
    conv1 = Activation('relu', name="Relu_AE01_1")(conv1) # 3
        
    decoded = Conv2D(3, (k_size, k_size), padding='same', name="Dense_AE01_2")(conv1) # 4
    decoded = BatchNormalization(name="BN_AE01_2")(decoded) # 5
    decoded = Activation('relu', name="Relu_AE01_2")(decoded) # 6
    return Model(input_img, decoded)

class AE01():
    def __init__(self, ksize, optimizer):
        self.optimizer = optimizer
        
        self.autoencoder = create_AE01_model(ksize)
        self.encoder = None

    def compile(self, optimizer='adam', loss='binary_crossentropy'):
        self.autoencoder.compile(optimizer=self.optimizer, loss=loss)

    def train(self, x_train=None, x_test=None, epochs=1, batch_size=32, shuffle=True):
        es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
        ae_model_path = '../models/AE/AE01_AE_Best.hdf5'
        cp_cb = ModelCheckpoint(filepath = ae_model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
       
        history = self.autoencoder.fit(x_train, x_train,
                             epochs=epochs,
                             batch_size=batch_size,
                             shuffle=shuffle,
                             callbacks=[es_cb, cp_cb],
                             validation_data=(x_test, x_test))
        
        self.autoencoder.load_weights(ae_model_path)
        
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        encode_model_path = '../models/AE/AE01_Encoder_Best.hdf5'
        self.encoder.save(encode_model_path)
        return history
    
    def load_weights(self, ae_model_path, encode_model_path):
        self.autoencoder.load_weights(ae_model_path)
        self.encoder = Model(self.autoencoder.input, self.autoencoder.get_layer('Relu_AE01_1').output)
        self.encoder.load_weights(encode_model_path)

# %%
ae_ksize = 3
ae_optimizer = 'rmsprop'
stack01 = AE01(ae_ksize, ae_optimizer)
stack01.load_weights('../models/AE/AE01_AE_Best.hdf5', '../models/AE/AE01_Encoder_Best.hdf5')
stack01.encoder.trainable = False
stack01.encoder.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# =================================================================
# Total params: 2,048
# Trainable params: 0
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ## Train

# %% [markdown]
# #### Create Model AE to CNN Ver 2 change 6 layer -> 12 layer

# %%
def create_StackedAE01_CNN01_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(output) # 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(x) # 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(x) # 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 16,16,64
    
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 7
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 8,8,128

    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 8
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 9
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 10
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(256)(x) # 11
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    y = Dense(10,activation = "softmax")(x) # 12

    return Model(input_img, y)

model01 = create_StackedAE01_CNN01_model(stack01.encoder)
model01.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_9 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 2,031,946
# Trainable params: 2,026,698
# Non-trainable params: 5,248
# _________________________________________________________________

# %% [markdown]
# #### Train without data augumentation

# %%
adam = Adam() # defalut
model01.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

# one hot encoding
nb_classes = 10
y_train_removed_onehot = to_categorical(y_train_removed, nb_classes)
y_valid_removed_onehot = to_categorical(y_valid_removed, nb_classes)
y_test_onehot = to_categorical(y_test, nb_classes)

# %%
# %%time

# train
saveDir = "../models/CNN/"

es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
chkpt = saveDir + 'Model_025_Best.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

model01_history = model01.fit(x_train_removed, y_train_removed_onehot,
                      batch_size=32,
                      epochs=400,
                      verbose=1,
                      validation_data=(x_valid_removed, y_valid_removed_onehot),
                      callbacks=[es_cb, cp_cb],
                      shuffle=True)
# Out:
# Epoch 1/400
# 930/930 [==============================] - ETA: 0s - loss: 1.5263 - accuracy: 0.4479
# Epoch 00001: val_loss improved from inf to 1.68890, saving model to ../models/CNN\Model_025_Best.hdf5
# 930/930 [==============================] - 11s 12ms/step - loss: 1.5263 - accuracy: 0.4479 - val_loss: 1.6889 - val_accuracy: 0.4174
# Epoch 2/400
# 928/930 [============================>.] - ETA: 0s - loss: 1.0814 - accuracy: 0.6213
# Epoch 00002: val_loss improved from 1.68890 to 1.04484, saving model to ../models/CNN\Model_025_Best.hdf5
# 930/930 [==============================] - 11s 11ms/step - loss: 1.0812 - accuracy: 0.6214 - val_loss: 1.0448 - val_accuracy: 0.6380
# Epoch 3/400
# 930/930 [==============================] - ETA: 0s - loss: 0.8177 - accuracy: 0.7179
# Epoch 00003: val_loss improved from 1.04484 to 0.96988, saving model to ../models/CNN\Model_025_Best.hdf5
# 930/930 [==============================] - 10s 11ms/step - loss: 0.8177 - accuracy: 0.7179 - val_loss: 0.9699 - val_accuracy: 0.6744
# Epoch 4/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.6648 - accuracy: 0.7715
# Epoch 00004: val_loss improved from 0.96988 to 0.69865, saving model to ../models/CNN\Model_025_Best.hdf5
# 930/930 [==============================] - 10s 11ms/step - loss: 0.6646 - accuracy: 0.7716 - val_loss: 0.6987 - val_accuracy: 0.7638
# Epoch 5/400
# 925/930 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.8150
# Epoch 00005: val_loss did not improve from 0.69865
# 930/930 [==============================] - 10s 11ms/step - loss: 0.5375 - accuracy: 0.8151 - val_loss: 0.7332 - val_accuracy: 0.7500
# Epoch 6/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.4489 - accuracy: 0.8435
# Epoch 00006: val_loss did not improve from 0.69865
# 930/930 [==============================] - 10s 11ms/step - loss: 0.4491 - accuracy: 0.8433 - val_loss: 0.7214 - val_accuracy: 0.7577
# Epoch 7/400
# 930/930 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.8747
# Epoch 00007: val_loss improved from 0.69865 to 0.65869, saving model to ../models/CNN\Model_025_Best.hdf5
# 930/930 [==============================] - 10s 11ms/step - loss: 0.3582 - accuracy: 0.8747 - val_loss: 0.6587 - val_accuracy: 0.7893
# Epoch 8/400
# 925/930 [============================>.] - ETA: 0s - loss: 0.2870 - accuracy: 0.9001
# Epoch 00008: val_loss did not improve from 0.65869
# 930/930 [==============================] - 10s 11ms/step - loss: 0.2872 - accuracy: 0.8999 - val_loss: 0.6834 - val_accuracy: 0.7902
# Epoch 9/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.9202
# Epoch 00009: val_loss did not improve from 0.65869
# 930/930 [==============================] - 10s 11ms/step - loss: 0.2285 - accuracy: 0.9203 - val_loss: 0.7286 - val_accuracy: 0.7901
# Epoch 10/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9389
# Epoch 00010: val_loss did not improve from 0.65869
# 930/930 [==============================] - 10s 11ms/step - loss: 0.1779 - accuracy: 0.9389 - val_loss: 0.7352 - val_accuracy: 0.7958
# Epoch 00010: early stopping
# Wall time: 1min 46s

# %%
# plot training
mdoel01_hist_df = pd.DataFrame(model01_history.history)

plt.figure()
mdoel01_hist_df[['loss', 'val_loss']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')

plt.figure()
mdoel01_hist_df[['accuracy', 'val_accuracy']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
model01.load_weights('../models/CNN/Model_025_Best.hdf5')
model01.evaluate(x_test, y_test_onehot)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7081 - accuracy: 0.7813
# [0.7081124186515808, 0.7813000082969666]

# %%
y_pred = model01.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      1000
#            1       0.93      0.78      0.85      1000
#            2       0.78      0.64      0.70      1000
#            3       0.58      0.71      0.64      1000
#            4       0.87      0.59      0.70      1000
#            5       0.72      0.74      0.73      1000
#            6       0.82      0.89      0.85      1000
#            7       0.83      0.83      0.83      1000
#            8       0.93      0.85      0.88      1000
#            9       0.70      0.95      0.81      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.79      0.78      0.78     10000
# weighted avg       0.79      0.78      0.78     10000

# %% [markdown]
# #### Create Model AE to CNN Ver 3 change 6 layer -> 15 layer

# %%
def create_StackedAE01_CNN02_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(output) # 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(x) # 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64,(3,3),padding = "same",activation= "relu")(x) # 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 16,16,64
    
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128,(3,3),padding = "same",activation= "relu")(x) # 7
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 8,8,128

    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 8
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 9
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256,(3,3),padding = "same",activation= "relu")(x) # 10
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(512,(3,3),padding = "same",activation= "relu")(x) # 11
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(512,(3,3),padding = "same",activation= "relu")(x) # 12
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(512,(3,3),padding = "same",activation= "relu")(x) # 13
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) # 4,4,256
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(256)(x) # 14
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    y = Dense(10,activation = "softmax")(x) # 15

    return Model(input_img, y)

model02 = create_StackedAE01_CNN02_model(stack01.encoder)
model02.summary()
# Out:
# Model: "functional_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# Dense_AE01_1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# BN_AE01_1 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# Relu_AE01_1 (Activation)     (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_114 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_114 (Activation)  (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_115 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_115 (Activation)  (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_116 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_116 (Activation)  (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_117 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_117 (Activation)  (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_118 (Activation)  (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_119 (Activation)  (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_120 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_121 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_122 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_126 (Conv2D)          (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_123 (Activation)  (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_124 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_124 (Activation)  (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_125 (Activation)  (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# global_average_pooling2d_9 ( (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_126 (Bat (None, 256)               1024
# _________________________________________________________________
# activation_126 (Activation)  (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 8,003,402
# Trainable params: 7,995,082
# Non-trainable params: 8,320
# _________________________________________________________________

# %%
adam = Adam() # defalut
model02.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

# one hot encoding
nb_classes = 10
y_train_removed_onehot = to_categorical(y_train_removed, nb_classes)
y_valid_removed_onehot = to_categorical(y_valid_removed, nb_classes)
y_test_onehot = to_categorical(y_test, nb_classes)

# %%
# %%time

# train
saveDir = "../models/CNN/"

es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
chkpt = saveDir + 'Model_026_Best.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

model02_history = model02.fit(x_train_removed, y_train_removed_onehot,
                      batch_size=32,
                      epochs=400,
                      verbose=1,
                      validation_data=(x_valid_removed, y_valid_removed_onehot),
                      callbacks=[es_cb, cp_cb],
                      shuffle=True)
# Out:
# Epoch 1/400
# 930/930 [==============================] - ETA: 0s - loss: 1.6140 - accuracy: 0.4139
# Epoch 00001: val_loss improved from inf to 1.58718, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 1.6140 - accuracy: 0.4139 - val_loss: 1.5872 - val_accuracy: 0.4453
# Epoch 2/400
# 928/930 [============================>.] - ETA: 0s - loss: 1.2291 - accuracy: 0.5691
# Epoch 00002: val_loss improved from 1.58718 to 1.29621, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 1.2290 - accuracy: 0.5692 - val_loss: 1.2962 - val_accuracy: 0.5318
# Epoch 3/400
# 928/930 [============================>.] - ETA: 0s - loss: 1.0012 - accuracy: 0.6535
# Epoch 00003: val_loss improved from 1.29621 to 1.07891, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 1.0012 - accuracy: 0.6535 - val_loss: 1.0789 - val_accuracy: 0.6472
# Epoch 4/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.8360 - accuracy: 0.7154
# Epoch 00004: val_loss improved from 1.07891 to 0.86440, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 0.8357 - accuracy: 0.7156 - val_loss: 0.8644 - val_accuracy: 0.7059
# Epoch 5/400
# 930/930 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.7564
# Epoch 00005: val_loss improved from 0.86440 to 0.84382, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 0.7053 - accuracy: 0.7564 - val_loss: 0.8438 - val_accuracy: 0.7123
# Epoch 6/400
# 927/930 [============================>.] - ETA: 0s - loss: 0.5942 - accuracy: 0.7961
# Epoch 00006: val_loss did not improve from 0.84382
# 930/930 [==============================] - 17s 19ms/step - loss: 0.5944 - accuracy: 0.7960 - val_loss: 0.9924 - val_accuracy: 0.6794
# Epoch 7/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.4961 - accuracy: 0.8325
# Epoch 00007: val_loss improved from 0.84382 to 0.70040, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 0.4961 - accuracy: 0.8325 - val_loss: 0.7004 - val_accuracy: 0.7667
# Epoch 8/400
# 930/930 [==============================] - ETA: 0s - loss: 0.4277 - accuracy: 0.8558
# Epoch 00008: val_loss did not improve from 0.70040
# 930/930 [==============================] - 16s 17ms/step - loss: 0.4277 - accuracy: 0.8558 - val_loss: 0.7595 - val_accuracy: 0.7576
# Epoch 9/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.3494 - accuracy: 0.8799
# Epoch 00009: val_loss improved from 0.70040 to 0.69940, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 0.3494 - accuracy: 0.8799 - val_loss: 0.6994 - val_accuracy: 0.7835
# Epoch 10/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.9046
# Epoch 00010: val_loss improved from 0.69940 to 0.66426, saving model to ../models/CNN\Model_026_Best.hdf5
# 930/930 [==============================] - 16s 17ms/step - loss: 0.2887 - accuracy: 0.9045 - val_loss: 0.6643 - val_accuracy: 0.7950
# Epoch 11/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.2396 - accuracy: 0.9205
# Epoch 00011: val_loss did not improve from 0.66426
# 930/930 [==============================] - 16s 17ms/step - loss: 0.2396 - accuracy: 0.9204 - val_loss: 0.7109 - val_accuracy: 0.7942
# Epoch 12/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.1936 - accuracy: 0.9343
# Epoch 00012: val_loss did not improve from 0.66426
# 930/930 [==============================] - 16s 17ms/step - loss: 0.1936 - accuracy: 0.9343 - val_loss: 0.6973 - val_accuracy: 0.8002
# Epoch 13/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.1542 - accuracy: 0.9493
# Epoch 00013: val_loss did not improve from 0.66426
# 930/930 [==============================] - 16s 17ms/step - loss: 0.1540 - accuracy: 0.9493 - val_loss: 0.7363 - val_accuracy: 0.8031
# Epoch 00013: early stopping
# Wall time: 3min 32s

# %%
# plot training
model02_hist_df = pd.DataFrame(model02_history.history)

plt.figure()
model02_hist_df[['loss', 'val_loss']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')

plt.figure()
model02_hist_df[['accuracy', 'val_accuracy']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
model02.load_weights('../models/CNN/Model_026_Best.hdf5')
model02.evaluate(x_test, y_test_onehot)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.7022 - accuracy: 0.7844
# [0.7022432684898376, 0.7843999862670898]

# %%
y_pred = model02.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      1000
#            1       0.95      0.85      0.90      1000
#            2       0.83      0.54      0.65      1000
#            3       0.58      0.73      0.65      1000
#            4       0.76      0.73      0.75      1000
#            5       0.73      0.72      0.73      1000
#            6       0.80      0.85      0.82      1000
#            7       0.73      0.88      0.80      1000
#            8       0.93      0.81      0.87      1000
#            9       0.86      0.88      0.87      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.80      0.78      0.78     10000
# weighted avg       0.80      0.78      0.78     10000

# %% [markdown]
# #### Create Model AE to CNN Ver 4 change 6 layer -> 15 layer like ResNet

# %%
def create_StackedAE01_CNN03_model(encoder):
    input_img = encoder.input
    output = encoder.layers[-1].output # 32,32,64
    x = Conv2D(64,(5,5),padding = "same",activation= "relu")(output) # 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x1 = MaxPooling2D(pool_size=(2, 2))(x) # 16,16,64
    
    x2 = Conv2D(64,(3,3),padding = "same",activation= "relu")(x1) # 3
    x2 = BatchNormalization()(x2)
    x2 = Activation('relu')(x2)
    x2 = Conv2D(64,(3,3),padding = "same",activation= "relu")(x2) # 4
    x2 = BatchNormalization()(x2)
    x2 = Activation('relu')(x2)
    
    x3 = Add()([x1, x2])
    
    x4 = Conv2D(64,(3,3),padding = "same",activation= "relu")(x3) # 5
    x4 = BatchNormalization()(x4)
    x4 = Activation('relu')(x4)
    x4 = Conv2D(64,(3,3),padding = "same",activation= "relu")(x4) # 6
    x4 = BatchNormalization()(x4)
    x4 = Activation('relu')(x4)
    
    x5 = Add()([x3, x4])

    x6 = Conv2D(128,(3,3),padding = "same",activation= "relu")(x5) # 7
    x6 = BatchNormalization()(x6)
    x6 = Activation('relu')(x6)
    x6 = Conv2D(128,(3,3),padding = "same",activation= "relu")(x6) # 8
    x6 = BatchNormalization()(x6)
    x6 = Activation('relu')(x6)
    
    x5 = Conv2D(128,(1,1),padding = "same",activation= "relu")(x6)
    x7 = Add()([x5, x6])
               
    x8 = Conv2D(128,(3,3),padding = "same",activation= "relu")(x7) # 9
    x8 = BatchNormalization()(x8)
    x8 = Activation('relu')(x8)
    x8 = Conv2D(128,(3,3),padding = "same",activation= "relu")(x8) # 10
    x8 = BatchNormalization()(x8)
    x8 = Activation('relu')(x8)
    
    x9 = Add()([x7, x8])
               
    x10 = Conv2D(256,(3,3),padding = "same",activation= "relu")(x9) # 11
    x10 = BatchNormalization()(x10)
    x10 = Activation('relu')(x10)
    x10 = Conv2D(256,(3,3),padding = "same",activation= "relu")(x10) # 12
    x10 = BatchNormalization()(x10)
    x10 = Activation('relu')(x10)
    
    x9 = Conv2D(256,(1,1),padding = "same",activation= "relu")(x9)
    x11 = Add()([x9, x10])
    
    x12 = Conv2D(256,(3,3),padding = "same",activation= "relu")(x11) # 13
    x12 = BatchNormalization()(x12)
    x12 = Activation('relu')(x12)
    x12 = Conv2D(256,(3,3),padding = "same",activation= "relu")(x12) # 14
    x12 = BatchNormalization()(x12)
    x12 = Activation('relu')(x12)
                
    x13 = Add()([x11, x12])
    x13 = MaxPooling2D(pool_size=(2, 2))(x13) # 8, 8 256         
    x13 = GlobalAveragePooling2D()(x13)
    x14 = Dense(256)(x13) # 15
    x14 = BatchNormalization()(x14)
    x14 = Activation("relu")(x14)
    y = Dense(10,activation = "softmax")(x14) # 16

    return Model(input_img, y)

model03 = create_StackedAE01_CNN03_model(stack01.encoder)
model03.summary()
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# Dense_AE01_1 (Conv2D)           (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# BN_AE01_1 (BatchNormalization)  (None, 32, 32, 64)   256         Dense_AE01_1[0][0]
# __________________________________________________________________________________________________
# Relu_AE01_1 (Activation)        (None, 32, 32, 64)   0           BN_AE01_1[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 32, 32, 64)   102464      Relu_AE01_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 32, 32, 64)   256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 32, 32, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 16, 16, 64)   0           activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 64)   36928       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 64)   256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 16, 16, 64)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 16, 16, 64)   36928       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 16, 16, 64)   256         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 16, 16, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 16, 16, 64)   0           max_pooling2d_17[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 64)   36928       add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 64)   256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 16, 16, 64)   36928       activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 64)   256         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 64)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 16, 16, 64)   0           add_28[0][0]
#                                                                  activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 16, 16, 128)  73856       add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 128)  512         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 128)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 16, 128)  147584      activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 128)  512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 128)  0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 128)  16512       activation_106[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 128)  0           conv2d_109[0][0]
#                                                                  activation_106[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 128)  147584      add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 128)  512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 128)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 16, 128)  147584      activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 128)  512         conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 128)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 128)  0           add_30[0][0]
#                                                                  activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 16, 256)  295168      add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 16, 16, 256)  1024        conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 16, 16, 256)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 256)  590080      activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 16, 16, 256)  1024        conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 256)  33024       add_31[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 16, 16, 256)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 16, 16, 256)  0           conv2d_114[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 16, 256)  590080      add_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 16, 16, 256)  1024        conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 16, 16, 256)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 256)  590080      activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 16, 16, 256)  1024        conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 16, 16, 256)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 16, 256)  0           add_32[0][0]
#                                                                  activation_112[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 8, 8, 256)    0           add_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 256)          0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          65792       global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 256)          1024        dense_12[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 256)          0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           2570        activation_113[0][0]
# ==================================================================================================
# Total params: 2,960,586
# Trainable params: 2,954,314
# Non-trainable params: 6,272
# __________________________________________________________________________________________________

# %%
adam = Adam() # defalut
model03.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

# one hot encoding
nb_classes = 10
y_train_removed_onehot = to_categorical(y_train_removed, nb_classes)
y_valid_removed_onehot = to_categorical(y_valid_removed, nb_classes)
y_test_onehot = to_categorical(y_test, nb_classes)

# %%
# %%time

# train
saveDir = "../models/CNN/"

es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
chkpt = saveDir + 'Model_027_Best.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

model03_history = model03.fit(x_train_removed, y_train_removed_onehot,
                      batch_size=32,
                      epochs=400,
                      verbose=1,
                      validation_data=(x_valid_removed, y_valid_removed_onehot),
                      callbacks=[es_cb, cp_cb],
                      shuffle=True)
# Out:
# Epoch 1/400
# 930/930 [==============================] - ETA: 0s - loss: 1.5123 - accuracy: 0.4533
# Epoch 00001: val_loss improved from inf to 1.47789, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 1.5123 - accuracy: 0.4533 - val_loss: 1.4779 - val_accuracy: 0.4881
# Epoch 2/400
# 930/930 [==============================] - ETA: 0s - loss: 1.1525 - accuracy: 0.5918
# Epoch 00002: val_loss improved from 1.47789 to 1.17334, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 1.1525 - accuracy: 0.5918 - val_loss: 1.1733 - val_accuracy: 0.5899
# Epoch 3/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.9430 - accuracy: 0.6690
# Epoch 00003: val_loss improved from 1.17334 to 1.00646, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 0.9425 - accuracy: 0.6691 - val_loss: 1.0065 - val_accuracy: 0.6380
# Epoch 4/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.8036 - accuracy: 0.7201
# Epoch 00004: val_loss did not improve from 1.00646
# 930/930 [==============================] - 16s 18ms/step - loss: 0.8034 - accuracy: 0.7201 - val_loss: 1.1196 - val_accuracy: 0.6325
# Epoch 5/400
# 927/930 [============================>.] - ETA: 0s - loss: 0.6892 - accuracy: 0.7594
# Epoch 00005: val_loss improved from 1.00646 to 0.81996, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 0.6893 - accuracy: 0.7595 - val_loss: 0.8200 - val_accuracy: 0.7113
# Epoch 6/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.5950 - accuracy: 0.7925
# Epoch 00006: val_loss did not improve from 0.81996
# 930/930 [==============================] - 16s 18ms/step - loss: 0.5951 - accuracy: 0.7924 - val_loss: 0.8464 - val_accuracy: 0.7122
# Epoch 7/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.5162 - accuracy: 0.8184
# Epoch 00007: val_loss improved from 0.81996 to 0.81293, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 17s 18ms/step - loss: 0.5162 - accuracy: 0.8184 - val_loss: 0.8129 - val_accuracy: 0.7275
# Epoch 8/400
# 928/930 [============================>.] - ETA: 0s - loss: 0.4499 - accuracy: 0.8424
# Epoch 00008: val_loss did not improve from 0.81293
# 930/930 [==============================] - 16s 18ms/step - loss: 0.4499 - accuracy: 0.8424 - val_loss: 1.0824 - val_accuracy: 0.6787
# Epoch 9/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.3924 - accuracy: 0.8633
# Epoch 00009: val_loss improved from 0.81293 to 0.77259, saving model to ../models/CNN\Model_027_Best.hdf5
# 930/930 [==============================] - 20s 21ms/step - loss: 0.3926 - accuracy: 0.8633 - val_loss: 0.7726 - val_accuracy: 0.7530
# Epoch 10/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.3355 - accuracy: 0.8820
# Epoch 00010: val_loss did not improve from 0.77259
# 930/930 [==============================] - 17s 18ms/step - loss: 0.3355 - accuracy: 0.8820 - val_loss: 0.7944 - val_accuracy: 0.7634
# Epoch 11/400
# 929/930 [============================>.] - ETA: 0s - loss: 0.2908 - accuracy: 0.8981
# Epoch 00011: val_loss did not improve from 0.77259
# 930/930 [==============================] - 17s 18ms/step - loss: 0.2908 - accuracy: 0.8981 - val_loss: 0.9324 - val_accuracy: 0.7442
# Epoch 12/400
# 927/930 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.9155
# Epoch 00012: val_loss did not improve from 0.77259
# 930/930 [==============================] - 16s 18ms/step - loss: 0.2408 - accuracy: 0.9154 - val_loss: 1.0271 - val_accuracy: 0.7304
# Epoch 00012: early stopping
# Wall time: 3min 23s

# %%
model03.load_weights('../models/CNN/Model_027_Best.hdf5')
model03.evaluate(x_test, y_test_onehot)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7719 - accuracy: 0.7524
# [0.7718943953514099, 0.7523999810218811]

# %%
y_pred = model03.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80      1000
#            1       0.98      0.67      0.79      1000
#            2       0.69      0.67      0.68      1000
#            3       0.63      0.59      0.61      1000
#            4       0.75      0.72      0.74      1000
#            5       0.73      0.62      0.67      1000
#            6       0.70      0.90      0.78      1000
#            7       0.69      0.86      0.77      1000
#            8       0.76      0.94      0.84      1000
#            9       0.83      0.81      0.82      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.76      0.75      0.75     10000
# weighted avg       0.76      0.75      0.75     10000

# %% [markdown]
# #### Train with data augumentation & Ver2 CNN model

# %%
encoder = stack01.encoder
encoder.trainable = False
model01 = create_StackedAE01_CNN01_model(encoder) # transfer learning

adam = Adam() # defalut
model01.compile(loss = "categorical_crossentropy", optimizer = adam, metrics = ["accuracy"])

# %%
# %%time

# one hot encoding
nb_classes = 10
y_train_removed_onehot = to_categorical(y_train_removed, nb_classes)
y_valid_removed_onehot = to_categorical(y_valid_removed, nb_classes)
y_test_onehot = to_categorical(y_test, nb_classes)

es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
chkpt = saveDir + 'Model_028_Best.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, \
       monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=10,
#     shear_range=0.2,
    horizontal_flip=True,
#     vertical_flip=True,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
    zoom_range=0.1
#     channel_shift_range=0.2
    )

batch_size = 32
train_datagenerator = train_datagen.flow(x_train_removed, y_train_removed_onehot, batch_size)
valid_datagenerator = ImageDataGenerator().flow(x_valid_removed, y_valid_removed_onehot, batch_size)

model01_history = model01.fit_generator(train_datagenerator,
                              steps_per_epoch=int(len(x_train_removed)//batch_size),
                              epochs=400,
                              validation_data=valid_datagenerator,
                              validation_steps=int(len(x_valid_removed)//batch_size),
                              verbose=1,
                              shuffle=True,
                              callbacks=[es_cb, cp_cb])
# Out:
# Epoch 1/400
# 929/929 [==============================] - ETA: 0s - loss: 1.6518 - accuracy: 0.4050
# Epoch 00001: val_loss improved from inf to 1.62255, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 1.6518 - accuracy: 0.4050 - val_loss: 1.6226 - val_accuracy: 0.4530
# Epoch 2/400
# 929/929 [==============================] - ETA: 0s - loss: 1.2872 - accuracy: 0.5403
# Epoch 00002: val_loss improved from 1.62255 to 1.24713, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 1.2872 - accuracy: 0.5403 - val_loss: 1.2471 - val_accuracy: 0.5841
# Epoch 3/400
# 929/929 [==============================] - ETA: 0s - loss: 1.0598 - accuracy: 0.6309
# Epoch 00003: val_loss improved from 1.24713 to 1.00119, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 1.0598 - accuracy: 0.6309 - val_loss: 1.0012 - val_accuracy: 0.6577
# Epoch 4/400
# 927/929 [============================>.] - ETA: 0s - loss: 0.8944 - accuracy: 0.6924
# Epoch 00004: val_loss improved from 1.00119 to 0.98994, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 0.8945 - accuracy: 0.6924 - val_loss: 0.9899 - val_accuracy: 0.6781
# Epoch 5/400
# 927/929 [============================>.] - ETA: 0s - loss: 0.7824 - accuracy: 0.7339
# Epoch 00005: val_loss improved from 0.98994 to 0.82458, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 0.7823 - accuracy: 0.7340 - val_loss: 0.8246 - val_accuracy: 0.7188
# Epoch 6/400
# 929/929 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.7651
# Epoch 00006: val_loss did not improve from 0.82458
# 929/929 [==============================] - 15s 17ms/step - loss: 0.6915 - accuracy: 0.7651 - val_loss: 0.8341 - val_accuracy: 0.7207
# Epoch 7/400
# 929/929 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.7888
# Epoch 00007: val_loss did not improve from 0.82458
# 929/929 [==============================] - 15s 16ms/step - loss: 0.6235 - accuracy: 0.7888 - val_loss: 0.9773 - val_accuracy: 0.6961
# Epoch 8/400
# 926/929 [============================>.] - ETA: 0s - loss: 0.5683 - accuracy: 0.8079
# Epoch 00008: val_loss improved from 0.82458 to 0.57376, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 0.5686 - accuracy: 0.8077 - val_loss: 0.5738 - val_accuracy: 0.8049
# Epoch 9/400
# 927/929 [============================>.] - ETA: 0s - loss: 0.5182 - accuracy: 0.8244
# Epoch 00009: val_loss did not improve from 0.57376
# 929/929 [==============================] - 15s 16ms/step - loss: 0.5178 - accuracy: 0.8245 - val_loss: 0.6904 - val_accuracy: 0.7679
# Epoch 10/400
# 929/929 [==============================] - ETA: 0s - loss: 0.4650 - accuracy: 0.8421
# Epoch 00010: val_loss improved from 0.57376 to 0.51240, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 0.4650 - accuracy: 0.8421 - val_loss: 0.5124 - val_accuracy: 0.8255
# Epoch 11/400
# 928/929 [============================>.] - ETA: 0s - loss: 0.4293 - accuracy: 0.8551
# Epoch 00011: val_loss did not improve from 0.51240
# 929/929 [==============================] - 15s 17ms/step - loss: 0.4292 - accuracy: 0.8551 - val_loss: 0.5681 - val_accuracy: 0.8136
# Epoch 12/400
# 926/929 [============================>.] - ETA: 0s - loss: 0.3954 - accuracy: 0.8656
# Epoch 00012: val_loss did not improve from 0.51240
# 929/929 [==============================] - 16s 17ms/step - loss: 0.3951 - accuracy: 0.8657 - val_loss: 0.5751 - val_accuracy: 0.8147
# Epoch 13/400
# 929/929 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8795
# Epoch 00013: val_loss improved from 0.51240 to 0.50671, saving model to ../models/CNN\Model_028_Best.hdf5
# 929/929 [==============================] - 16s 17ms/step - loss: 0.3545 - accuracy: 0.8795 - val_loss: 0.5067 - val_accuracy: 0.8336
# Epoch 14/400
# 929/929 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8871
# Epoch 00014: val_loss did not improve from 0.50671
# 929/929 [==============================] - 16s 17ms/step - loss: 0.3328 - accuracy: 0.8871 - val_loss: 0.6560 - val_accuracy: 0.8011
# Epoch 15/400
# 929/929 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.9000
# Epoch 00015: val_loss did not improve from 0.50671
# 929/929 [==============================] - 16s 17ms/step - loss: 0.2994 - accuracy: 0.9000 - val_loss: 0.6240 - val_accuracy: 0.8094
# Epoch 16/400
# 929/929 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9057 ETA: 0s - loss: 0.273
# Epoch 00016: val_loss did not improve from 0.50671
# 929/929 [==============================] - 16s 17ms/step - loss: 0.2745 - accuracy: 0.9057 - val_loss: 0.5098 - val_accuracy: 0.8390
# Epoch 00016: early stopping
# Wall time: 4min 14s

# %%
# plot training
model01_hist_df = pd.DataFrame(model01_history.history)

plt.figure()
model01_hist_df[['loss', 'val_loss']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')

plt.figure()
model01_hist_df[['accuracy', 'val_accuracy']].plot()
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
model01.load_weights('../models/CNN/Model_028_Best.hdf5')
model01.evaluate(x_test, y_test_onehot)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.6148 - accuracy: 0.8042
# [0.6147642135620117, 0.8041999936103821]

# %%
y_pred = model01.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80      1000
#            1       0.87      0.96      0.91      1000
#            2       0.91      0.51      0.66      1000
#            3       0.62      0.73      0.67      1000
#            4       0.92      0.60      0.72      1000
#            5       0.67      0.81      0.73      1000
#            6       0.86      0.89      0.87      1000
#            7       0.79      0.91      0.85      1000
#            8       0.93      0.89      0.91      1000
#            9       0.92      0.84      0.88      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.82      0.80      0.80     10000
# weighted avg       0.82      0.80      0.80     10000
